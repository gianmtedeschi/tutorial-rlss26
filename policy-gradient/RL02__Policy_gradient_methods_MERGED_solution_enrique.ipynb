# %% [markdown]
# Reinforcement Learning Summer School 2026 Edition, Milan, Italy.
#
# Authors:
#
# *   Leonardo Cesani (leonardo.cesani@polimi.it)
# *   Enrique Mateos (enmateos@pa.uc3m.es)
# *   Gianmarco Tedeschi (gianmarco.tedeschi@polimi.it)
# *   Davide Tenedini (davide.tenedini@polimi.it)

# %% [markdown]
# ---
# # RL Basics II: Reinforcement Learning with Policy Gradient Methods
# ---
#
# Welcome to the second tutorial on RL Basics @ RLSS 2026!
#
# This notebook introduces a fundamental family of reinforcement learning algorithms: **policy gradient methods**. Many real-world problems involve continuous action spaces or complex environments where value-based methods struggle. Policy gradient methods offer an alternative by directly learning a parameterized policy, which makes them a natural fit for these problems.
#
# Our goal is to build and train an agent with policy gradients and neural networks, step by step. We work entirely in a **continuous control** setting, and along the way we implement and *run* the full progression of estimators that modern deep RL is built on, comparing each one against the previous:
#
# 1. **Policy gradients and the score function** — the objective, the policy gradient theorem, and how to represent a policy. We make the score function explicit on a linear-Gaussian policy.
# 2. **REINFORCE, GPOMDP and baselines** — the Monte-Carlo policy gradient, the reward-to-go (causal credit assignment) refinement, and variance reduction via a baseline, implemented with PyTorch autograd on a neural Gaussian policy.
# 3. **Actor-Critic methods** — replacing the fixed baseline with a learned value function, training an actor and a critic together.
#
# Each section pairs the theory you need with hands-on coding. We keep the notation and the code interfaces consistent throughout, so that every section builds directly on the previous one, and so that the four algorithms can be compared on the same plot at the end.
#
# Notation used throughout: policy parameters are $\boldsymbol{\theta}$; a trajectory is $\tau = (s_0, a_0, r_0, s_1, \dots)$ of horizon $H$; the index $t$ runs over time steps within a trajectory; $N$ is the number of trajectories (rollouts) in a batch; $\gamma$ is the discount factor; and $\hat{R}_t$ denotes the discounted reward-to-go from time $t$.

# %%
# Imports
import matplotlib.pyplot as plt
from matplotlib import animation
from matplotlib import rc
import seaborn as sns
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
from torch.distributions import Normal
import gymnasium as gym

# making plots pretty
sns.set_palette("deep")
rc('animation', html='jshtml')
import warnings
warnings.filterwarnings('ignore')

print("gymnasium", gym.__version__)

is_animated = True
# Out:
# gymnasium 1.2.3

# %% [markdown]
# ## Shared utilities
#
# The following helpers are used by every section: a function to evaluate an agent, a plotter that overlays training curves so we can compare algorithms, a rollout collector, and helpers to record and animate an episode. We define them once and reuse them throughout. Every training loop in this notebook calls the same `collect_rollouts` and `evaluate`, and every experiment appends its curve to a shared dictionary so that the final section can plot all of them together.
#
# For speed, we keep rendering separate from training. Training and evaluation use a plain environment, and `evaluate` averages the return over a small number of episodes. Rendering, which is comparatively slow, happens only in the animation cells, through `record_episode` on a dedicated rendering environment.

# %%
#@title Shared helper functions (run me)

# A dictionary that accumulates the training curve of every experiment,
# so that later sections can compare against earlier ones.
all_results = {}

# A fixed colour for each method, so every comparison plot is consistent.
METHOD_COLORS = {
    'REINFORCE (linear)':   'tab:blue',
    'REINFORCE (neural)':   'tab:orange',
    'REINFORCE + baseline': 'tab:green',
    'Actor-Critic':         'tab:red',
    'PPO (Stable-Baselines3)': 'tab:purple',
}


def seed_everything(seed):
    """Set the random seeds so that a training run is reproducible.

    Running the same cell twice with the same seed produces the same learning curve.
    The environment resets draw their own seeds from numpy below, so seeding numpy
    here is enough to make the collected trajectories reproducible too.
    """
    random.seed(seed)
    torch.manual_seed(seed)
    np.random.seed(seed)


def evaluate(env, policy, T, gamma=1., num_episodes=10):
    """Estimate the policy's performance by averaging the return over several episodes.

    :param env: the Gym environment to evaluate in.
    :param policy: a policy exposing a `draw_action` method.
    :param gamma: the discount factor applied to the rewards.
    :param num_episodes: how many episodes to average over.
    :return: the mean return and its standard error across the episodes.
    """
    gamma = 1
    all_episode_rewards = []
    for _ in range(num_episodes):
        episode_rewards = []
        done = False
        discounter = 1.
        obs = env.reset(seed=int(np.random.randint(2**31 - 1)))[0]
        t = 0
        while not done and t < T:
            action = policy.draw_action(obs)
            obs, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            episode_rewards.append(reward * discounter)
            discounter *= gamma
            t += 1
        all_episode_rewards.append(sum(episode_rewards))

    mean_episode_reward = np.mean(all_episode_rewards)
    std_episode_reward = (
        np.std(all_episode_rewards, ddof=1) / np.sqrt(num_episodes)
        if num_episodes > 1 else 0.
    )
    print("Mean reward:", round(mean_episode_reward, 2),
          "Std reward:", round(std_episode_reward, 2),
          "Num episodes:", num_episodes)
    return mean_episode_reward, std_episode_reward


def record_episode(env, policy):
    """Run a single episode and return the rendered frames, for animation."""
    frames = []
    obs = env.reset(seed=int(np.random.randint(2**31 - 1)))[0]
    done = False
    while not done:
        action = policy.draw_action(obs)
        obs, _, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        frames.append(env.render())
    return frames


def plot_results(results, label=None):
    """Plot the average return at each training iteration, with a shaded standard error."""
    _mean = np.array([m for m, _ in results])
    _std = np.array([s for _, s in results])
    iterations = np.arange(len(_mean))
    color = METHOD_COLORS.get(label)
    plt.plot(iterations, _mean, label=label, color=color)
    plt.fill_between(iterations, _mean - _std, _mean + _std, alpha=.2, color=color)
    plt.xlabel('Training iteration')
    plt.ylabel('Average return')
    if label:
        plt.legend(loc='lower right')


def compare_results(curves, title='Comparison'):
    """Overlay several named training curves on a single plot.

    :param curves: a dict mapping each method's name to its list of (mean, std) results.
    """
    plt.figure()
    for label, results in curves.items():
        plot_results(results, label=label)
    plt.title(title)
    plt.show()


def collect_rollouts(env, policy, m, T):
    """Run the policy in the environment to gather training data.

    :param m: the number of trajectories (rollouts) to collect.
    :param T: the maximum number of steps per trajectory.
    :return: a list of m trajectories, each a list of (state, action, reward) tuples.
    """
    trajectories = []
    for _ in range(m):
        s, _ = env.reset(seed=int(np.random.randint(2**31 - 1)))
        t = 0
        done = False
        trajectory = []
        while t < T and not done:
            a = policy.draw_action(s)
            s1, r, terminated, truncated, _ = env.step(a)
            done = terminated or truncated
            trajectory.append((s, a, r))
            s = s1
            t += 1
        trajectories.append(trajectory)
    return trajectories


def animate(data, interval=40):
    fig = plt.figure(1)
    img = plt.imshow(data[0])
    plt.axis('off')
    def _step(i):
        img.set_data(data[i])
    anim = animation.FuncAnimation(fig, _step, frames=len(data), interval=interval)
    plt.close(1)
    return anim

# %% [markdown]
# ---
# # 1. Introduction to Policy Gradient RL
# ---
#
# In this section we look at an alternative to value-based methods: policy gradient methods. The name comes from the fact that we estimate the gradient of the policy directly, rather than of a value function.
#
# To learn, we need an objective. In RL the general objective is to maximize the expected return collected by acting in the environment. Suppose the agent's policy is parameterized by $\boldsymbol{\theta}$, so that actions are drawn from $\pi_{\boldsymbol{\theta}}(a \mid s)$. A very general way to represent such a policy is a neural network with parameters $\boldsymbol{\theta}$. The task of RL is then to find the parameters that maximize
#
# $$J(\boldsymbol{\theta}) = \mathbb{E}_{\tau \sim \pi_{\boldsymbol{\theta}}}\,[\,R(\tau)\,],$$
#
# where $\tau$ is a trajectory and $R(\tau)$ its return.
#
# One way to maximize $J(\boldsymbol{\theta})$ is gradient ascent:
#
# $$\boldsymbol{\theta}_{k+1} = \boldsymbol{\theta}_k + \alpha\, \nabla_{\boldsymbol{\theta}} J(\boldsymbol{\theta})\big|_{\boldsymbol{\theta}_k},$$
#
# where $\alpha$ is the step size. The quantity $\nabla_{\boldsymbol{\theta}} J(\boldsymbol{\theta})$ is the policy gradient. The [policy gradient theorem](https://proceedings.neurips.cc/paper_files/paper/1999/file/464d828b85b0bed98e80ade0a5c43b0f-Paper.pdf) states that it can be written as an expectation over trajectories sampled from the current policy:
#
# $$\nabla_{\boldsymbol{\theta}} J(\boldsymbol{\theta}) = \mathbb{E}_{\tau \sim \pi_{\boldsymbol{\theta}}}\Big[\sum_{t=0}^{H-1} \nabla_{\boldsymbol{\theta}} \log \pi_{\boldsymbol{\theta}}(a_t \mid s_t)\, R(\tau)\Big].$$
#
# Informally, the policy gradient is the gradient of the log-probability of each chosen action, weighted by the return of the trajectory it belonged to. REINFORCE, which we build in Section 2, is the simplest algorithm exploiting this identity: it increases the probability of actions that tend to lead to high-return trajectories.
#
# The term $\nabla_{\boldsymbol{\theta}} \log \pi_{\boldsymbol{\theta}}(a \mid s)$ is called the score function. It is the central object of this first section: we compute it by hand for a simple policy before letting autograd take over in the sections that follow.

# %% [markdown]
# ## 1.1 The environment
#
# We use [InvertedPendulum-v5](https://gymnasium.farama.org/environments/mujoco/inverted_pendulum/), the MuJoCo continuous-control analogue of CartPole. A cart moves along a track and must keep a pole balanced upright. The crucial difference from CartPole is the action space:
#
# - The **state** is a 4-dimensional continuous vector (cart position and velocity, pole angle and angular velocity).
# - The **action** is a single continuous force applied to the cart, in the range $[-3, 3]$, rather than a discrete left/right choice.
# - The agent receives a reward of $+1$ for every timestep the pole stays upright, and the episode ends when the pole falls. The return of an episode is therefore the number of steps the agent kept the pole balanced.
#
# Because the action is continuous, we represent the policy with a **Gaussian** distribution over actions, rather than the categorical (softmax) distribution used for discrete environments. This choice is consistent across all three sections.
#
# Recap from Part 1: an *environment* is the task we want to solve; the agent interacts with it via an *action*, collects a *reward* that drives learning, and observes the next *state*. An *episode* (also called a *trajectory* or *rollout*) is the sequence of states, actions and rewards the agent experiences over time.

# %%
env_id = "InvertedPendulum-v5"

# Training and evaluation run on a plain env (no rendering) -- this is what keeps
# the notebook fast. A separate rendering env is used only to record animations.
env = gym.make(env_id)
render_env = gym.make(env_id, render_mode="rgb_array")

# State and action space sizes
s_size = env.observation_space.shape[0]
a_size = env.action_space.shape[0]

# %%
print("Observation space\n")
print("The state space is:", s_size)
print("Sample observation:", env.observation_space.sample())
# Out:
# Observation space
#
# The state space is: 4
# Sample observation: [ 0.68518206 -0.10432554 -0.96088346  0.72358787]

# %%
print("Action space\n")
print("The action space is:", a_size)
print("Action bounds:", env.action_space.low, "to", env.action_space.high)
print("Action space sample:", env.action_space.sample())
# Out:
# Action space
#
# The action space is: 1
# Action bounds: [-3.] to [3.]
# Action space sample: [2.1213458]

# %% [markdown]
# ## 1.2 Policies
#
# In RL a policy defines the behaviour of an agent by mapping states to actions. Formally a policy $\pi$ takes a state and returns an action. We distinguish:
#
# - A **deterministic policy** always returns the same action for a given state, $a = \pi(s)$.
# - A **stochastic policy** returns a distribution over actions, $\pi(a \mid s) = \mathbb{P}(a \mid s)$, from which the agent samples.
#
# Policy gradient methods need a differentiable, stochastic policy, so that the score $\nabla_{\boldsymbol{\theta}} \log \pi_{\boldsymbol{\theta}}(a \mid s)$ is well-defined. The policy network takes the current state as input and outputs the parameters of an action distribution; its weights are learned to maximize cumulative reward.
#
# For continuous actions we use a **Gaussian policy**,
#
# $$\pi_{\boldsymbol{\theta}}(a \mid s) = \mathcal{N}\big(\mu_{\boldsymbol{\theta}}(s),\, \sigma^2\big),$$
#
# where $\mu_{\boldsymbol{\theta}}(s)$ is the mean action predicted by the policy and $\sigma$ controls how much the agent explores around that mean. The log-probability of an action under this policy is
#
# $$\log \pi_{\boldsymbol{\theta}}(a \mid s) = -\frac{\lVert a - \mu_{\boldsymbol{\theta}}(s) \rVert^2}{2\sigma^2} - \log \sigma - \tfrac{1}{2}\log(2\pi),$$
#
# and, when the mean is a linear function $\mu_{\boldsymbol{\theta}}(s) = W s$, the score with respect to $W$ has the closed form
#
# $$\nabla_{W} \log \pi_{\boldsymbol{\theta}}(a \mid s) = \frac{\big(a - W s\big)\, s^\top}{\sigma^2}.$$
#
# We will use exactly this closed form in Section 1, then let autograd compute the equivalent gradient for a neural mean in Sections 2 and 3.

# %% [markdown]
# ### Two parameterizations
#
# We meet two ways of parameterizing the Gaussian mean:
#
# 1. **Linear policies** are simple, interpretable and fast. They are useful for understanding policy gradient methods, and on a balancing task like the inverted pendulum a linear feedback policy is already a reasonable controller.
# 2. **Neural-network policies** are more expressive, can model nonlinear behaviour, and are the standard in deep RL.
#
# In Section 1 we implement a linear-Gaussian policy and compute its score by hand. From Section 2 onward we use a neural Gaussian policy and let PyTorch autograd compute gradients for us. This staging is deliberate: first understand the score, then automate it. Both share the same `BasePolicy` interface, so the shared training utilities work with either.
#
# ---
#
# ### A brief reminder on PyTorch
#
# PyTorch is the deep-learning framework we use throughout. The concepts we rely on are:
#
# - [`torch.Tensor`](https://pytorch.org/docs/stable/tensors.html), multi-dimensional arrays similar to NumPy arrays that can run on GPUs.
# - [`nn.Module`](https://pytorch.org/docs/stable/generated/torch.nn.Module.html), the base class used to define neural networks and parameterized models.
# - Automatic differentiation: PyTorch computes gradients via `autograd`.
#
# ```python
# x = torch.tensor([2.0], requires_grad=True)
# y = x ** 2
# y.backward()
# print(x.grad)  # dy/dx = 2x = 4
# ```
#
# In policy gradient methods, gradients are what tell us how to nudge $\boldsymbol{\theta}$ to increase the expected return.
#
# ---
#
# Below is the common base class that all our policies inherit from. It fixes the interface (`draw_action`, `get_parameters`, `set_parameters`, and so on) used by the shared training utilities. It must not be modified.

# %%
class BasePolicy(nn.Module):
    """Common interface shared by every policy in this notebook."""
    def __init__(self):
        super().__init__()

    def forward(self, x):
        raise NotImplementedError

    def distribution(self, obs):
        raise NotImplementedError

    def draw_action(self, obs, deterministic=False):
        raise NotImplementedError

    def get_parameters(self):
        raise NotImplementedError

    def set_parameters(self, theta):
        raise NotImplementedError

    def log_prob(self, obs, action):
        raise NotImplementedError

    def grad_log(self, obs, action):
        raise NotImplementedError

# %% [markdown]
# We also define a small helper that builds a multi-layer perceptron from a tuple of hidden-layer sizes. It is reused by the neural Gaussian policy (Section 2) and by the actor-critic network (Section 3), so that the depth and width of every network in the notebook are controlled the same way, from the constructor.

# %%
def build_mlp(input_size, output_size, hidden_sizes=(64,), activation=nn.Tanh, is_critic=False):
    """
    Build a simple MLP. Reused by the neural policy and the actor-critic network.
    The depth and width are set entirely by `hidden_sizes`, e.g. (64,) or (64, 64).
    """
    layers = []
    in_features = input_size
    for h in hidden_sizes:
        layers.append(nn.Linear(in_features, h))
        layers.append(activation())
        in_features = h

    layers.append(nn.Linear(in_features, output_size))
    if not is_critic:
        layers.append(nn.Tanh())

    return nn.Sequential(*layers)

# %% [markdown]
# ### ⭐ Exercise 1.1 — Linear-Gaussian policy and its score
#
# We start with a shallow policy whose mean is a linear transformation of the state, $\mu_{\boldsymbol{\theta}}(s) = W s$, with a fixed exploration standard deviation $\sigma$. This policy has a single weight matrix $W$, so the score function has the closed form given above and we can compute it by hand.
#
# Fill in the three gaps:
#
# 1. In `forward`, compute the mean by multiplying the weight matrix by the observation (use the matrix-multiplication operator `@`).
# 2. In `draw_action`, sample an action by adding Gaussian noise of scale $\sigma$ to the mean (see [`torch.randn_like`](https://pytorch.org/docs/stable/generated/torch.randn_like.html)).
# 3. In `grad_log`, implement the closed-form score $\big(a - Ws\big)s^\top / \sigma^2$ (see [`torch.outer`](https://pytorch.org/docs/stable/generated/torch.outer.html)), returned as a flat vector of length `self.dim`.

# %%
class ShallowGaussianPolicy(BasePolicy):
    """Linear-Gaussian policy with a manually computed score (teaching device)."""
    def __init__(self, s_size, a_size, std=0.5):
        super().__init__()
        self.s_size = s_size
        self.a_size = a_size
        self.dim = a_size * s_size               # number of parameters in W
        self.W = torch.randn(a_size, s_size, requires_grad=False) * 0.1
        self.std = torch.tensor(std, requires_grad=False)

    def forward(self, x):
        # --- WRITE YOUR SOLUTION HERE --- #
        mean = self.W @ x                        # SOLUTION
        # --- END SOLUTION --- #
        return mean

    def draw_action(self, obs, deterministic=False):
        mu = self.forward(torch.from_numpy(obs).float())
        if deterministic:
            return mu.detach().numpy()
        # --- WRITE YOUR SOLUTION HERE --- #
        epsilon = torch.randn_like(mu) * self.std    # SOLUTION
        # --- END SOLUTION --- #
        action = mu + epsilon
        return action.detach().numpy()

    def get_parameters(self):
        return self.W.detach().numpy().ravel()

    def set_parameters(self, theta):
        self.W = torch.from_numpy(theta.reshape(self.a_size, self.s_size)).float()

    def log_prob(self, obs, action):
        mu = self.forward(torch.from_numpy(obs).float())
        diff = torch.as_tensor(action).float() - mu
        return -0.5 * torch.sum(diff ** 2) / (self.std ** 2) \
               - torch.log(self.std) - 0.5 * np.log(2 * np.pi)

    def grad_log(self, obs, action):
        """Score nabla_theta log pi(a|s), returned as a flat vector of length self.dim."""
        obs_t = torch.from_numpy(obs).float()
        action_t = torch.as_tensor(action).float()
        mu = self.forward(obs_t)
        # --- WRITE YOUR SOLUTION HERE --- #
        diff = action_t - mu                                 # SOLUTION
        score = torch.outer(diff, obs_t) / (self.std ** 2)   # SOLUTION
        # --- END SOLUTION --- #
        return score.ravel()

# %% [markdown]
# ### ⭐ Exercise 1.2 — Neural Gaussian policy
#
# The neural policy replaces the linear mean with an MLP, $\mu_{\boldsymbol{\theta}}(s) = \text{MLP}_{\boldsymbol{\theta}}(s)$, and makes the log standard deviation a learnable parameter so the agent can adjust its own exploration. We no longer compute the score by hand: from here on, autograd differentiates `log_prob` for us.
#
# Fill in the two gaps:
#
# 1. In `distribution`, build a [`Normal`](https://pytorch.org/docs/stable/distributions.html#normal) distribution with the network's mean and the standard deviation `self.log_std.exp()`.
# 2. In `draw_action`, sample an action from that distribution (or return the mean when `deterministic=True`).

# %%
class GaussianPolicy(BasePolicy):
    """Neural Gaussian policy: an MLP predicts the mean, with a learnable log-std.
    Gradients are obtained via autograd, so no manual score is needed.
    """
    def __init__(self, s_size, a_size, exploration_std=0.1, hidden_sizes=(64,), activation=nn.Tanh):
        super().__init__()
        self.s_size = s_size
        self.a_size = a_size
        self.network = build_mlp(s_size, a_size, hidden_sizes, activation)

        if exploration_std <= 0:
            raise ValueError(f"exploration_std must be positive, got {exploration_std}")
        self.log_std = nn.Parameter(
            torch.log(torch.full((a_size,), float(exploration_std)))
        )

    def forward(self, x):
        return self.network(x)

    def distribution(self, obs):
        mean = self.forward(obs)
        # --- WRITE YOUR SOLUTION HERE --- #
        dist = Normal(mean, self.log_std.exp())      # SOLUTION
        # --- END SOLUTION --- #
        return dist

    def draw_action(self, obs, deterministic=False):
        obs_t = torch.from_numpy(obs).float()
        with torch.no_grad():
            if deterministic:
                return self.forward(obs_t).numpy()
            # --- WRITE YOUR SOLUTION HERE --- #
            return self.distribution(obs_t).sample().numpy()   # SOLUTION
            # --- END SOLUTION --- #

    def log_prob(self, obs, action):
        """Sum the per-dimension log-probabilities of `action` under the policy."""
        dist = self.distribution(obs)
        return dist.log_prob(action).sum(-1)

    def get_parameters(self):
        return nn.utils.parameters_to_vector(self.parameters()).detach()

    def set_parameters(self, theta):
        nn.utils.vector_to_parameters(
            torch.as_tensor(theta, dtype=torch.float32), self.parameters()
        )

# %% [markdown]
# Before training anything, we check that both policies behave as expected: the linear-Gaussian score should be a flat vector of length `s_size * a_size`, and the neural policy should return an action of the right shape.

# %%
# Sanity checks
obs = env.reset()[0]

gauss_linear = ShallowGaussianPolicy(s_size, a_size)
score = gauss_linear.grad_log(obs, np.zeros(a_size))
print("Linear-Gaussian score shape:", tuple(score.shape), "(expected", (s_size * a_size,), ")")

gauss_nn = GaussianPolicy(s_size, a_size, hidden_sizes=(64,))
action = gauss_nn.draw_action(obs)
print("Neural policy sampled action:", action, "(expected shape", (a_size,), ")")
# Out:
# Linear-Gaussian score shape: (4,) (expected (4,) )
# Neural policy sampled action: [0.0843779] (expected shape (1,) )

# %% [markdown]
# ---
# # 2. Policy Gradient Methods: REINFORCE, GPOMDP and Baselines
# ---
#
# Policy gradient methods directly optimize a parameterized stochastic policy $\pi_{\boldsymbol{\theta}}(a \mid s)$ to maximize the expected return. Unlike value-based methods, which derive a policy implicitly from value estimates, they estimate the gradient of the expected return and perform gradient ascent directly on $\boldsymbol{\theta}$.
#
# Recall the objective and its gradient from Section 1:
#
# $$J(\boldsymbol{\theta}) = \mathbb{E}_{\tau \sim \pi_{\boldsymbol{\theta}}}[R(\tau)],
# \qquad
# \nabla_{\boldsymbol{\theta}} J(\boldsymbol{\theta}) = \mathbb{E}_{\tau \sim \pi_{\boldsymbol{\theta}}}\Big[\sum_{t=0}^{H-1} \nabla_{\boldsymbol{\theta}} \log \pi_{\boldsymbol{\theta}}(a_t \mid s_t)\, R(\tau)\Big].$$
#
# This lets us estimate the gradient from sampled trajectories. The generic procedure is iterative: collect data, estimate the gradient, update the parameters, and repeat.
#
# **Algorithm 1 — Policy Gradient (PG)**
# ***
# **Input:** MDP $\mathcal{M}$, number of iterations $T$, learning-rate schedule $(\eta^{(t)})_{t=0}^{T-1}$<br>
# **Output:** approximately optimal parameters $\boldsymbol{\theta}^{(T)}$
#
# 1. Initialize $\boldsymbol{\theta}^{(0)}$ arbitrarily.
# 2. **for** $t = 0, 1, \dots, T-1$ **do**
#     - Estimate the policy gradient $\widehat{\nabla}_{\boldsymbol{\theta}} J(\boldsymbol{\theta}^{(t)})$.
#     - Update $\boldsymbol{\theta}^{(t+1)} = \boldsymbol{\theta}^{(t)} + \eta^{(t)}\, \widehat{\nabla}_{\boldsymbol{\theta}} J(\boldsymbol{\theta}^{(t)})$.
# 3. **end for**
# 4. **return** $\boldsymbol{\theta}^{(T)}$
# ***
#
# In Algorithm 1, the index $t$ denotes the outer training iteration. In the derivations below, $t$ denotes the time step within a trajectory and $H$ the horizon.

# %% [markdown]
# ## 2.1 REINFORCE and the reward-to-go (GPOMDP)
#
# [REINFORCE](https://link.springer.com/content/pdf/10.1007/BF00992696.pdf) is the Monte-Carlo policy gradient: it estimates the gradient from complete sampled episodes. It is unbiased, because the expectation of the sample gradient equals the true gradient, but it suffers from high variance.
#
# The variance has two sources. First, weighting every action by the full trajectory return $R(\tau) = \sum_{t=0}^{H-1} \gamma^t r(s_t, a_t)$ aggregates randomness from the dynamics, the rewards and the policy across the entire horizon. Second, and more subtly, the naive estimator violates temporal causality: an action $a_t$ is weighted by rewards collected *before* $t$, which it could not possibly have influenced. Assigning credit for outcomes an action could not affect injects noise.
#
# The remedy follows from the principle that an action at time $t$ can only affect future rewards. We replace the full return with the reward-to-go, the discounted sum of rewards from $t$ onward:
#
# $$\hat{R}_t = \sum_{t'=t}^{H-1} \gamma^{t' - t}\, r(s_{t'}, a_{t'}).$$
#
# Substituting it reduces the variance without introducing bias, which gives the estimator
#
# $$\nabla_{\boldsymbol{\theta}} J(\boldsymbol{\theta}) \approx \frac{1}{N} \sum_{i=1}^{N} \sum_{t=0}^{H-1} \nabla_{\boldsymbol{\theta}} \log \pi_{\boldsymbol{\theta}}(a_{i,t} \mid s_{i,t})\, \hat{R}_{i,t}.$$
#
# An algebraically equivalent form, the [GPOMDP](https://arxiv.org/pdf/1106.0665) estimator, is convenient when working with explicit scores. It accumulates the cumulative sum of scores weighted by the discounted reward at each step:
#
# $$\nabla_{\boldsymbol{\theta}}^{\text{GPOMDP}} J(\boldsymbol{\theta}) = \frac{1}{N} \sum_{i=1}^{N} \sum_{t=0}^{H-1} \gamma^t r(s_{i,t}, a_{i,t}) \sum_{l=0}^{t} \nabla_{\boldsymbol{\theta}} \log \pi_{\boldsymbol{\theta}}(a_{i,l} \mid s_{i,l}).$$
#
# We implement this twice: first with the explicit hand-computed score on the linear policy from Section 1, then with autograd on the neural policy. The two are mathematically the same estimator; the difference is only in how the score is obtained.
#
# A note on naming. "REINFORCE" originally refers to the Monte-Carlo policy gradient, and the reward-to-go form we just derived is sometimes given the separate name GPOMDP. In practice the reward-to-go version is what almost everyone means by REINFORCE today, so to keep the comparison readable we use a single name throughout and distinguish the variants by what differs between them: **REINFORCE (linear)** and **REINFORCE (neural)** for the two policy parameterizations, **REINFORCE + baseline** once we add variance reduction, and **Actor-Critic** for the learned-baseline version in Section 3. All of them use the reward-to-go estimator above.

# %% [markdown]
# ### ⭐ Exercise 2.1 — GPOMDP with the explicit score (linear policy)
#
# Implement the GPOMDP estimator for the linear policy using the manually computed score `policy.grad_log`. You are given a `(H, dim)` tensor of per-step scores and an `(H, 1)` tensor of discounted rewards.
#
# Hint: use [`torch.cumsum`](https://pytorch.org/docs/stable/generated/torch.cumsum.html) along the time axis to accumulate the scores $\sum_{l=0}^{t} \nabla_{\boldsymbol{\theta}} \log \pi$, multiply by the discounted rewards, and sum over the horizon.

# %%
def gpomdp_linear(rollouts, policy, gamma):
    """GPOMDP estimator using an explicit, hand-computed score (linear-Gaussian policy).
    Returns a flat gradient vector, to be used with manual gradient ascent.
    """
    grad = 0
    for roll in rollouts:
        H = len(roll)
        disc_rew = torch.zeros((H, 1))
        scores = torch.zeros((H, policy.dim))

        # Retrieve the per-step score and discounted reward
        for t in range(H):
            s, a, r = roll[t]
            disc_rew[t] = (gamma ** t) * r
            scores[t] = policy.grad_log(s, a)

        # --- WRITE YOUR SOLUTION HERE --- #
        cum_scores = torch.cumsum(scores, dim=0)            # SOLUTION
        grad += torch.sum(cum_scores * disc_rew, dim=0)     # SOLUTION
        # --- END SOLUTION --- #

    return grad / len(rollouts)

# %% [markdown]
# We train the linear policy with a simple loop that performs manual gradient ascent: get the parameters, add the (learning-rate-scaled) gradient, and set them back. This is the most literal possible implementation of Algorithm 1, and it makes clear what the optimizer will later do for us automatically.

# %%
def train_linear(env, policy, gamma, m, K, alpha, T):
    """Train a linear policy by gradient ascent with the reward-to-go estimator.

    :param m: rollouts collected per iteration.
    :param K: number of training iterations.
    :param alpha: the gradient-ascent step size.
    :param T: maximum trajectory length.
    :return: a list of (mean_return, standard_error), one entry per iteration.
    """
    results = [evaluate(env, policy, T, gamma)]

    for k in range(K):
        print('Iteration:', k)
        rollouts = collect_rollouts(env, policy, m, T)

        theta = policy.get_parameters()
        pg = gpomdp_linear(rollouts, policy, gamma).numpy()
        policy.set_parameters(theta + alpha * pg)

        results.append(evaluate(env, policy, T, gamma))

    return results

# %% [markdown]
# ### ⭐ Exercise 2.2 — Run the linear policy
#
# Run the linear policy on the inverted pendulum. A linear feedback controller is already a sensible policy for a balancing task, so you should see the return climb steadily, although it tends to be noisy because the gradient estimate is high-variance and the learning rate is constant.
#
# We store the resulting curve in `all_results` so that the later sections can compare against it.

# %%
discount_factor = 0.99   # @param
batch_size = 50           # @param  (rollouts per iteration, N)
iterations = 100           # @param
learning_rate = 0.001      # @param
trajectory_length = 500   # @param  (native episode cap is 1000)
exploration_std = 0.1     # @param
seed = 0                  # @param

seed_everything(seed)

# Instantiate and train the linear policy
linear_policy = ShallowGaussianPolicy(s_size, a_size, std=exploration_std)
linear_results = train_linear(env, linear_policy, discount_factor, batch_size,
                              iterations, learning_rate, trajectory_length)

all_results['REINFORCE (linear)'] = linear_results
# Out:
# Mean reward: 19.6 Std reward: 1.86 Num episodes: 10
# Iteration: 0
# Mean reward: 21.0 Std reward: 1.98 Num episodes: 10
# Iteration: 1
# Mean reward: 22.0 Std reward: 2.17 Num episodes: 10
# Iteration: 2
# Mean reward: 19.0 Std reward: 1.65 Num episodes: 10
# Iteration: 3
# Mean reward: 22.2 Std reward: 2.38 Num episodes: 10
# Iteration: 4
# Mean reward: 21.2 Std reward: 1.95 Num episodes: 10
# Iteration: 5
# Mean reward: 23.5 Std reward: 2.7 Num episodes: 10
# Iteration: 6
# Mean reward: 29.4 Std reward: 2.95 Num episodes: 10
# Iteration: 7
# Mean reward: 22.7 Std reward: 2.33 Num episodes: 10
# Iteration: 8
# Mean reward: 25.9 Std reward: 2.68 Num episodes: 10
# Iteration: 9
# Mean reward: 24.5 Std reward: 1.94 Num episodes: 10
# Iteration: 10
# Mean reward: 33.9 Std reward: 3.53 Num episodes: 10
# Iteration: 11
# Mean reward: 34.6 Std reward: 3.87 Num episodes: 10
# Iteration: 12
# Mean reward: 34.3 Std reward: 3.36 Num episodes: 10
# Iteration: 13
# Mean reward: 29.9 Std reward: 2.35 Num episodes: 10
# Iteration: 14
# Mean reward: 35.4 Std reward: 3.01 Num episodes: 10
# Iteration: 15
# Mean reward: 32.0 Std reward: 2.65 Num episodes: 10
# Iteration: 16
# Mean reward: 30.3 Std reward: 2.51 Num episodes: 10
# Iteration: 17
# Mean reward: 28.4 Std reward: 1.36 Num episodes: 10
# Iteration: 18
# Mean reward: 38.0 Std reward: 5.69 Num episodes: 10
# Iteration: 19
# Mean reward: 34.0 Std reward: 4.38 Num episodes: 10
# Iteration: 20
# Mean reward: 36.2 Std reward: 2.21 Num episodes: 10
# Iteration: 21
# Mean reward: 36.2 Std reward: 2.69 Num episodes: 10
# Iteration: 22
# Mean reward: 37.4 Std reward: 3.24 Num episodes: 10
# Iteration: 23
# Mean reward: 44.4 Std reward: 3.54 Num episodes: 10
# Iteration: 24
# Mean reward: 44.2 Std reward: 5.47 Num episodes: 10
# Iteration: 25
# Mean reward: 45.3 Std reward: 4.23 Num episodes: 10
# Iteration: 26
# Mean reward: 46.8 Std reward: 4.63 Num episodes: 10
# Iteration: 27
# Mean reward: 39.9 Std reward: 2.94 Num episodes: 10
# Iteration: 28
# Mean reward: 57.7 Std reward: 5.8 Num episodes: 10
# Iteration: 29
# Mean reward: 52.6 Std reward: 5.81 Num episodes: 10
# Iteration: 30
# Mean reward: 67.0 Std reward: 5.73 Num episodes: 10
# Iteration: 31
# Mean reward: 66.6 Std reward: 3.31 Num episodes: 10
# Iteration: 32
# Mean reward: 67.7 Std reward: 3.45 Num episodes: 10
# Iteration: 33
# Mean reward: 62.0 Std reward: 6.8 Num episodes: 10
# Iteration: 34
# Mean reward: 67.7 Std reward: 3.07 Num episodes: 10
# Iteration: 35
# Mean reward: 68.4 Std reward: 3.23 Num episodes: 10
# Iteration: 36
# Mean reward: 69.7 Std reward: 4.28 Num episodes: 10
# Iteration: 37
# Mean reward: 80.3 Std reward: 4.16 Num episodes: 10
# Iteration: 38
# Mean reward: 72.1 Std reward: 6.85 Num episodes: 10
# Iteration: 39
# Mean reward: 75.4 Std reward: 4.11 Num episodes: 10
# Iteration: 40
# Mean reward: 79.5 Std reward: 6.9 Num episodes: 10
# Iteration: 41
# Mean reward: 74.3 Std reward: 3.44 Num episodes: 10
# Iteration: 42
# Mean reward: 75.2 Std reward: 5.51 Num episodes: 10
# Iteration: 43
# Mean reward: 80.8 Std reward: 3.85 Num episodes: 10
# Iteration: 44
# Mean reward: 87.0 Std reward: 3.39 Num episodes: 10
# Iteration: 45
# Mean reward: 84.4 Std reward: 5.57 Num episodes: 10
# Iteration: 46
# Mean reward: 100.3 Std reward: 8.03 Num episodes: 10
# Iteration: 47
# Mean reward: 114.9 Std reward: 14.4 Num episodes: 10
# Iteration: 48
# Mean reward: 124.1 Std reward: 11.21 Num episodes: 10
# Iteration: 49
# Mean reward: 139.7 Std reward: 9.1 Num episodes: 10
# Iteration: 50
# Mean reward: 147.7 Std reward: 12.98 Num episodes: 10
# Iteration: 51
# Mean reward: 114.8 Std reward: 5.31 Num episodes: 10
# Iteration: 52
# Mean reward: 111.8 Std reward: 6.23 Num episodes: 10
# Iteration: 53
# Mean reward: 93.1 Std reward: 5.55 Num episodes: 10
# Iteration: 54
# Mean reward: 114.6 Std reward: 5.02 Num episodes: 10
# Iteration: 55
# Mean reward: 154.8 Std reward: 13.9 Num episodes: 10
# Iteration: 56
# Mean reward: 131.6 Std reward: 12.48 Num episodes: 10
# Iteration: 57
# Mean reward: 132.1 Std reward: 11.76 Num episodes: 10
# Iteration: 58
# Mean reward: 169.1 Std reward: 11.62 Num episodes: 10
# Iteration: 59
# Mean reward: 164.0 Std reward: 8.74 Num episodes: 10
# Iteration: 60
# Mean reward: 157.3 Std reward: 12.32 Num episodes: 10
# Iteration: 61
# Mean reward: 190.4 Std reward: 11.4 Num episodes: 10
# Iteration: 62
# Mean reward: 180.5 Std reward: 12.28 Num episodes: 10
# Iteration: 63
# Mean reward: 181.8 Std reward: 10.34 Num episodes: 10
# Iteration: 64
# Mean reward: 164.4 Std reward: 10.02 Num episodes: 10
# Iteration: 65
# Mean reward: 192.6 Std reward: 11.22 Num episodes: 10
# Iteration: 66
# Mean reward: 175.8 Std reward: 11.76 Num episodes: 10
# Iteration: 67
# Mean reward: 114.0 Std reward: 7.61 Num episodes: 10
# Iteration: 68
# Mean reward: 201.7 Std reward: 20.7 Num episodes: 10
# Iteration: 69
# Mean reward: 212.5 Std reward: 16.39 Num episodes: 10
# Iteration: 70
# Mean reward: 213.6 Std reward: 10.22 Num episodes: 10
# Iteration: 71
# Mean reward: 148.2 Std reward: 8.08 Num episodes: 10
# Iteration: 72
# Mean reward: 121.8 Std reward: 14.15 Num episodes: 10
# Iteration: 73
# Mean reward: 142.0 Std reward: 16.68 Num episodes: 10
# Iteration: 74
# Mean reward: 185.2 Std reward: 23.98 Num episodes: 10
# Iteration: 75
# Mean reward: 164.7 Std reward: 9.51 Num episodes: 10
# Iteration: 76
# Mean reward: 173.5 Std reward: 7.41 Num episodes: 10
# Iteration: 77
# Mean reward: 193.0 Std reward: 18.89 Num episodes: 10
# Iteration: 78
# Mean reward: 141.9 Std reward: 9.39 Num episodes: 10
# Iteration: 79
# Mean reward: 137.6 Std reward: 12.51 Num episodes: 10
# Iteration: 80
# Mean reward: 131.6 Std reward: 3.55 Num episodes: 10
# Iteration: 81
# Mean reward: 116.7 Std reward: 12.02 Num episodes: 10
# Iteration: 82
# Mean reward: 203.7 Std reward: 11.87 Num episodes: 10
# Iteration: 83
# Mean reward: 209.3 Std reward: 22.62 Num episodes: 10
# Iteration: 84
# Mean reward: 178.3 Std reward: 11.92 Num episodes: 10
# Iteration: 85
# Mean reward: 104.4 Std reward: 6.19 Num episodes: 10
# Iteration: 86
# Mean reward: 156.3 Std reward: 21.85 Num episodes: 10
# Iteration: 87
# Mean reward: 272.8 Std reward: 29.79 Num episodes: 10
# Iteration: 88
# Mean reward: 186.3 Std reward: 10.15 Num episodes: 10
# Iteration: 89
# Mean reward: 208.4 Std reward: 10.87 Num episodes: 10
# Iteration: 90
# Mean reward: 220.8 Std reward: 9.43 Num episodes: 10
# Iteration: 91
# Mean reward: 145.9 Std reward: 8.42 Num episodes: 10
# Iteration: 92
# Mean reward: 189.2 Std reward: 18.2 Num episodes: 10
# Iteration: 93
# Mean reward: 208.7 Std reward: 18.08 Num episodes: 10
# Iteration: 94
# Mean reward: 206.4 Std reward: 22.01 Num episodes: 10
# Iteration: 95
# Mean reward: 222.1 Std reward: 6.02 Num episodes: 10
# Iteration: 96
# Mean reward: 251.3 Std reward: 15.11 Num episodes: 10
# Iteration: 97
# Mean reward: 265.0 Std reward: 18.56 Num episodes: 10
# Iteration: 98
# Mean reward: 181.5 Std reward: 12.4 Num episodes: 10
# Iteration: 99
# Mean reward: 182.0 Std reward: 13.92 Num episodes: 10

# %%
plt.figure()
plot_results(linear_results, label='REINFORCE (linear)')
plt.title('REINFORCE with a linear policy on InvertedPendulum')
plt.show()

# %%
# Watch the trained linear policy balance the pole
if is_animated:
    frames = record_episode(render_env, linear_policy)
    animate(frames)

# %% [markdown]
# ## 2.2 REINFORCE for any network, via a surrogate loss
#
# Computing the score by hand only works for simple policies. For a neural policy we instead build a scalar **surrogate loss** whose gradient with respect to $\boldsymbol{\theta}$ is exactly the GPOMDP estimator, and let autograd do the rest:
#
# $$\mathcal{L}(\boldsymbol{\theta}) = \frac{1}{N} \sum_{i=1}^{N} \sum_{t=0}^{H-1} \hat{R}_{i,t} \, \log \pi_{\boldsymbol{\theta}}(a_{i,t} \mid s_{i,t}).$$
#
# Differentiating $\mathcal{L}$ reproduces the reward-to-go estimator, because the reward-to-go is treated as a constant weight on each log-probability. Since we maximize $J$, the training loop will minimize $-\mathcal{L}$. The function below therefore returns the scalar loss $\mathcal{L}$, and the optimizer handles the sign.
#
# ### ⭐ Exercise 2.3 — Surrogate-loss REINFORCE
#
# Fill in the computation of the discounted reward-to-go.
#
# Hint: compute it in reverse order to properly accumulate the discount factor. You can use builtin function `reversed()`

# %%
def reinforce(rollouts, policy, gamma, baseline=False):
    """
    Surrogate-loss REINFORCE (reward-to-go / GPOMDP) for any autograd policy.
    Returns the scalar loss L; the training loop minimizes -L (i.e. ascends J).
    If baseline=True, subtracts the batch-mean reward-to-go (see Section 2.3).
    """
    # Pre-compute the discounted rewards-to-go for every rollout
    all_rewards_to_go = []
    for roll in rollouts:
        H = len(roll)
        
        # --- WRITE YOUR SOLUTION HERE --- #
        rewards_to_go = torch.zeros(H)
        G = 0.0
        for t in reversed(range(H)):
            G = roll[t][2] + gamma * G
            rewards_to_go[t] = G
        # --- END SOLUTION --- #
        all_rewards_to_go.append(rewards_to_go)

    # Optional average baseline (Section 2.3)
    weights = torch.cat(all_rewards_to_go)
    b = torch.mean(weights) if baseline else 0.0

    # Stack every transition and score them in one pass
    states = torch.tensor(
        np.array([s for roll in rollouts for (s, _, _) in roll]), dtype=torch.float32
    )
    actions = torch.tensor(
        np.array([a for roll in rollouts for (_, a, _) in roll]), dtype=torch.float32
    )
    log_probs = policy.log_prob(states, actions)

    total_loss = torch.sum((weights - b) * log_probs)
    return total_loss / len(rollouts)

# %% [markdown]
# Because the estimator returns a scalar loss, we can use a standard PyTorch optimizer: we maximize $J$ by minimizing $-\mathcal{L}$. This is the same training pattern we reuse, almost verbatim, for the actor-critic in Section 3.

# %%
def train(env, policy, gamma, m, K, alpha, T, baseline=False):
    """Train a policy with the autograd reward-to-go REINFORCE estimator.

    :param baseline: if True, subtract the average reward-to-go as a baseline.
    :return: a list of (mean_return, standard_error), one entry per iteration.
    """
    optimizer = optim.Adam(policy.parameters(), lr=alpha)
    results = [evaluate(env, policy, T, gamma)]

    for k in range(K):
        print('Iteration:', k)
        rollouts = collect_rollouts(env, policy, m, T)

        loss = reinforce(rollouts, policy, gamma, baseline=baseline)
        optimizer.zero_grad()
        (-loss).backward()           # maximize the objective by minimizing its negative
        optimizer.step()

        results.append(evaluate(env, policy, T, gamma))

    return results

# %% [markdown]
# ### ⭐ Exercise 2.4 — Run the neural policy and compare
#
# Train the neural Gaussian policy with `baseline=False`. Then plot its curve together with the linear policy's curve from Section 2.1. Because the network is more expressive, it should reach a similar or higher return; the comparison also lets you see how the two estimators behave under the same budget.

# %%
discount_factor = 0.99       # @param
batch_size = 50           # @param  (rollouts per iteration, N)
iterations = 100           # @param
learning_rate = 0.005     # @param
trajectory_length = 500   # @param  (native episode cap is 1000)
n_hidden = (32, 32)       # @param
exploration_std = 0.5     # @param
seed = 0                  # @param

seed_everything(seed)

# Instantiate and train the neural policy (no baseline yet)
nn_policy = GaussianPolicy(s_size, a_size, exploration_std, hidden_sizes=n_hidden)
reinforce_results = train(env, nn_policy, discount_factor, batch_size,
                          iterations, learning_rate, trajectory_length,
                          baseline=False)

all_results['REINFORCE (neural)'] = reinforce_results
# Out:
# Mean reward: 7.5 Std reward: 0.52 Num episodes: 10
# Iteration: 0
# Mean reward: 12.2 Std reward: 1.45 Num episodes: 10
# Iteration: 1
# Mean reward: 17.4 Std reward: 3.6 Num episodes: 10
# Iteration: 2
# Mean reward: 16.8 Std reward: 3.12 Num episodes: 10
# Iteration: 3
# Mean reward: 12.3 Std reward: 1.45 Num episodes: 10
# Iteration: 4
# Mean reward: 20.0 Std reward: 3.05 Num episodes: 10
# Iteration: 5
# Mean reward: 26.0 Std reward: 4.14 Num episodes: 10
# Iteration: 6
# Mean reward: 28.0 Std reward: 4.04 Num episodes: 10
# Iteration: 7
# Mean reward: 36.0 Std reward: 7.03 Num episodes: 10
# Iteration: 8
# Mean reward: 34.2 Std reward: 3.71 Num episodes: 10
# Iteration: 9
# Mean reward: 43.7 Std reward: 6.88 Num episodes: 10
# Iteration: 10
# Mean reward: 64.4 Std reward: 6.65 Num episodes: 10
# Iteration: 11
# Mean reward: 72.3 Std reward: 21.45 Num episodes: 10
# Iteration: 12
# Mean reward: 65.1 Std reward: 10.39 Num episodes: 10
# Iteration: 13
# Mean reward: 74.8 Std reward: 11.75 Num episodes: 10
# Iteration: 14
# Mean reward: 79.2 Std reward: 11.15 Num episodes: 10
# Iteration: 15
# Mean reward: 80.5 Std reward: 9.69 Num episodes: 10
# Iteration: 16
# Mean reward: 82.3 Std reward: 11.88 Num episodes: 10
# Iteration: 17
# Mean reward: 104.1 Std reward: 17.6 Num episodes: 10
# Iteration: 18
# Mean reward: 104.7 Std reward: 16.45 Num episodes: 10
# Iteration: 19
# Mean reward: 109.2 Std reward: 13.02 Num episodes: 10
# Iteration: 20
# Mean reward: 107.2 Std reward: 17.44 Num episodes: 10
# Iteration: 21
# Mean reward: 83.9 Std reward: 11.37 Num episodes: 10
# Iteration: 22
# Mean reward: 162.9 Std reward: 21.19 Num episodes: 10
# Iteration: 23
# Mean reward: 113.6 Std reward: 11.58 Num episodes: 10
# Iteration: 24
# Mean reward: 127.3 Std reward: 13.97 Num episodes: 10
# Iteration: 25
# Mean reward: 134.7 Std reward: 18.34 Num episodes: 10
# Iteration: 26
# Mean reward: 150.8 Std reward: 19.83 Num episodes: 10
# Iteration: 27
# Mean reward: 140.2 Std reward: 10.89 Num episodes: 10
# Iteration: 28
# Mean reward: 129.1 Std reward: 13.56 Num episodes: 10
# Iteration: 29
# Mean reward: 109.6 Std reward: 7.75 Num episodes: 10
# Iteration: 30
# Mean reward: 135.8 Std reward: 15.01 Num episodes: 10
# Iteration: 31
# Mean reward: 172.6 Std reward: 7.57 Num episodes: 10
# Iteration: 32
# Mean reward: 145.5 Std reward: 9.77 Num episodes: 10
# Iteration: 33
# Mean reward: 149.1 Std reward: 8.58 Num episodes: 10
# Iteration: 34
# Mean reward: 207.7 Std reward: 21.75 Num episodes: 10
# Iteration: 35
# Mean reward: 157.1 Std reward: 20.69 Num episodes: 10
# Iteration: 36
# Mean reward: 194.0 Std reward: 16.38 Num episodes: 10
# Iteration: 37
# Mean reward: 246.5 Std reward: 18.77 Num episodes: 10
# Iteration: 38
# Mean reward: 211.8 Std reward: 45.72 Num episodes: 10
# Iteration: 39
# Mean reward: 242.0 Std reward: 37.13 Num episodes: 10
# Iteration: 40
# Mean reward: 207.6 Std reward: 36.27 Num episodes: 10
# Iteration: 41
# Mean reward: 184.5 Std reward: 19.58 Num episodes: 10
# Iteration: 42
# Mean reward: 209.0 Std reward: 18.97 Num episodes: 10
# Iteration: 43
# Mean reward: 326.5 Std reward: 41.08 Num episodes: 10
# Iteration: 44
# Mean reward: 402.8 Std reward: 44.0 Num episodes: 10
# Iteration: 45
# Mean reward: 455.8 Std reward: 18.94 Num episodes: 10
# Iteration: 46
# Mean reward: 388.3 Std reward: 49.69 Num episodes: 10
# Iteration: 47
# Mean reward: 482.0 Std reward: 17.89 Num episodes: 10
# Iteration: 48
# Mean reward: 355.3 Std reward: 47.27 Num episodes: 10
# Iteration: 49
# Mean reward: 440.9 Std reward: 41.27 Num episodes: 10
# Iteration: 50
# Mean reward: 402.8 Std reward: 37.13 Num episodes: 10
# Iteration: 51
# Mean reward: 442.0 Std reward: 35.22 Num episodes: 10
# Iteration: 52
# Mean reward: 456.2 Std reward: 29.21 Num episodes: 10
# Iteration: 53
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 54
# Mean reward: 474.4 Std reward: 25.6 Num episodes: 10
# Iteration: 55
# Mean reward: 464.8 Std reward: 35.2 Num episodes: 10
# Iteration: 56
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 57
# Mean reward: 478.7 Std reward: 19.9 Num episodes: 10
# Iteration: 58
# Mean reward: 452.2 Std reward: 29.81 Num episodes: 10
# Iteration: 59
# Mean reward: 429.2 Std reward: 29.1 Num episodes: 10
# Iteration: 60
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 61
# Mean reward: 473.0 Std reward: 27.0 Num episodes: 10
# Iteration: 62
# Mean reward: 448.7 Std reward: 42.43 Num episodes: 10
# Iteration: 63
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 64
# Mean reward: 403.7 Std reward: 53.72 Num episodes: 10
# Iteration: 65
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 66
# Mean reward: 481.0 Std reward: 19.0 Num episodes: 10
# Iteration: 67
# Mean reward: 476.1 Std reward: 23.9 Num episodes: 10
# Iteration: 68
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 69
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 70
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 71
# Mean reward: 472.1 Std reward: 27.9 Num episodes: 10
# Iteration: 72
# Mean reward: 473.9 Std reward: 26.1 Num episodes: 10
# Iteration: 73
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 74
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 75
# Mean reward: 465.5 Std reward: 34.5 Num episodes: 10
# Iteration: 76
# Mean reward: 496.7 Std reward: 3.3 Num episodes: 10
# Iteration: 77
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 78
# Mean reward: 470.8 Std reward: 20.01 Num episodes: 10
# Iteration: 79
# Mean reward: 481.5 Std reward: 18.5 Num episodes: 10
# Iteration: 80
# Mean reward: 437.6 Std reward: 41.63 Num episodes: 10
# Iteration: 81
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 82
# Mean reward: 459.2 Std reward: 40.8 Num episodes: 10
# Iteration: 83
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 84
# Mean reward: 495.8 Std reward: 4.2 Num episodes: 10
# Iteration: 85
# Mean reward: 355.0 Std reward: 73.84 Num episodes: 10
# Iteration: 86
# Mean reward: 401.4 Std reward: 65.73 Num episodes: 10
# Iteration: 87
# Mean reward: 401.2 Std reward: 65.87 Num episodes: 10
# Iteration: 88
# Mean reward: 6.9 Std reward: 0.53 Num episodes: 10
# Iteration: 89
# Mean reward: 16.1 Std reward: 5.53 Num episodes: 10
# Iteration: 90
# Mean reward: 12.9 Std reward: 4.61 Num episodes: 10
# Iteration: 91
# Mean reward: 6.7 Std reward: 0.4 Num episodes: 10
# Iteration: 92
# Mean reward: 7.4 Std reward: 0.43 Num episodes: 10
# Iteration: 93
# Mean reward: 9.3 Std reward: 2.8 Num episodes: 10
# Iteration: 94
# Mean reward: 9.0 Std reward: 2.82 Num episodes: 10
# Iteration: 95
# Mean reward: 6.6 Std reward: 0.31 Num episodes: 10
# Iteration: 96
# Mean reward: 6.5 Std reward: 0.17 Num episodes: 10
# Iteration: 97
# Mean reward: 6.5 Std reward: 0.22 Num episodes: 10
# Iteration: 98
# Mean reward: 5.6 Std reward: 0.31 Num episodes: 10
# Iteration: 99
# Mean reward: 6.2 Std reward: 0.2 Num episodes: 10

# %%
# Compare against the linear policy from Section 2.1
compare_results(
    {'REINFORCE (linear)': all_results['REINFORCE (linear)'],
     'REINFORCE (neural)': all_results['REINFORCE (neural)']},
    title='Linear vs. neural REINFORCE'
)

# %%
# Watch the trained neural policy
if is_animated:
    frames = record_episode(render_env, nn_policy)
    animate(frames)

# %% [markdown]
# ## 2.3 Baselines
#
# A well-known way to reduce the variance further is to subtract a baseline $b$ from the reward-to-go:
#
# $$\nabla_{\boldsymbol{\theta}} J(\boldsymbol{\theta}) \approx \frac{1}{N} \sum_{i=1}^{N} \sum_{t=0}^{H-1} \nabla_{\boldsymbol{\theta}} \log \pi_{\boldsymbol{\theta}}(a_{i,t} \mid s_{i,t}) \big(\hat{R}_{i,t} - b\big).$$
#
# This stays unbiased as long as $b$ does not depend on the action $a_{i,t}$, which follows from the log-derivative trick:
#
# $$\mathbb{E}_{\pi_{\boldsymbol{\theta}}}\big[\nabla_{\boldsymbol{\theta}} \log \pi_{\boldsymbol{\theta}}(a_t \mid s_t)\, b\big] = b\, \nabla_{\boldsymbol{\theta}} \underbrace{\sum_a \pi_{\boldsymbol{\theta}}(a \mid s_t)}_{=\,1} = 0.$$
#
# So subtracting $b$ leaves the expectation of the estimator unchanged while reducing its variance. Two common choices are:
#
# - A **constant baseline** $b = c$, a fixed scalar such as the average return over a long window. It is simple but does not adapt to the current policy.
# - An **average baseline**, the mean reward-to-go over the current batch,
# $$b = \frac{1}{N} \sum_{i=1}^{N} \frac{1}{H} \sum_{t=0}^{H-1} \hat{R}_{i,t},$$
# which adapts automatically at each iteration and requires no extra hyperparameters. This is the most common simple choice, and it is the one our `reinforce` function implements when `baseline=True`.
#
# In Section 3 we go one step further and let the baseline depend on the state, $b = V(s_t)$, learned by a neural network. That is the actor-critic approach.

# %% [markdown]
# ### ⭐ Exercise 2.5 — Add the average baseline and compare
#
# The `reinforce` function already supports the average baseline through its `baseline` flag: when set, it computes $b$ as the mean of all rewards-to-go across the batch and subtracts it from each $\hat{R}_{i,t}$.
#
# Before running, predict the effect: subtracting a constant baseline does not change the expected gradient, so the mean curve should be similar, but the variance of the updates should drop, which often shows up as a smoother curve or a tighter shaded band. Train with `baseline=True` and overlay all three curves to check.

# %%
discount_factor = 0.99       # @param
batch_size = 50           # @param  (rollouts per iteration, N)
iterations = 100           # @param
learning_rate = 0.005      # @param
trajectory_length = 500   # @param  (native episode cap is 1000)
n_hidden = (32, 32)       # @param
exploration_std = 0.5     # @param
seed = 0                  # @param

seed_everything(seed)

# Same policy and budget as Exercise 2.4, now with the average baseline
nn_policy_bl = GaussianPolicy(s_size, a_size, exploration_std, hidden_sizes=n_hidden)
baseline_results = train(env, nn_policy_bl, discount_factor, batch_size,
                         iterations, learning_rate, trajectory_length,
                         baseline=True)

all_results['REINFORCE + baseline'] = baseline_results
# Out:
# Mean reward: 7.5 Std reward: 0.52 Num episodes: 10
# Iteration: 0
# Mean reward: 10.6 Std reward: 1.3 Num episodes: 10
# Iteration: 1
# Mean reward: 14.7 Std reward: 2.47 Num episodes: 10
# Iteration: 2
# Mean reward: 14.7 Std reward: 2.06 Num episodes: 10
# Iteration: 3
# Mean reward: 18.7 Std reward: 5.19 Num episodes: 10
# Iteration: 4
# Mean reward: 21.4 Std reward: 2.86 Num episodes: 10
# Iteration: 5
# Mean reward: 30.0 Std reward: 4.68 Num episodes: 10
# Iteration: 6
# Mean reward: 33.0 Std reward: 4.01 Num episodes: 10
# Iteration: 7
# Mean reward: 33.9 Std reward: 5.35 Num episodes: 10
# Iteration: 8
# Mean reward: 29.0 Std reward: 5.66 Num episodes: 10
# Iteration: 9
# Mean reward: 62.6 Std reward: 9.02 Num episodes: 10
# Iteration: 10
# Mean reward: 56.4 Std reward: 6.21 Num episodes: 10
# Iteration: 11
# Mean reward: 63.9 Std reward: 10.48 Num episodes: 10
# Iteration: 12
# Mean reward: 63.2 Std reward: 11.99 Num episodes: 10
# Iteration: 13
# Mean reward: 70.2 Std reward: 11.45 Num episodes: 10
# Iteration: 14
# Mean reward: 75.7 Std reward: 14.16 Num episodes: 10
# Iteration: 15
# Mean reward: 73.7 Std reward: 9.33 Num episodes: 10
# Iteration: 16
# Mean reward: 114.0 Std reward: 13.21 Num episodes: 10
# Iteration: 17
# Mean reward: 84.4 Std reward: 8.24 Num episodes: 10
# Iteration: 18
# Mean reward: 86.5 Std reward: 10.53 Num episodes: 10
# Iteration: 19
# Mean reward: 88.2 Std reward: 13.78 Num episodes: 10
# Iteration: 20
# Mean reward: 128.1 Std reward: 18.4 Num episodes: 10
# Iteration: 21
# Mean reward: 99.9 Std reward: 12.88 Num episodes: 10
# Iteration: 22
# Mean reward: 140.7 Std reward: 14.37 Num episodes: 10
# Iteration: 23
# Mean reward: 83.8 Std reward: 8.45 Num episodes: 10
# Iteration: 24
# Mean reward: 92.9 Std reward: 10.86 Num episodes: 10
# Iteration: 25
# Mean reward: 128.9 Std reward: 16.37 Num episodes: 10
# Iteration: 26
# Mean reward: 112.6 Std reward: 15.06 Num episodes: 10
# Iteration: 27
# Mean reward: 118.3 Std reward: 12.64 Num episodes: 10
# Iteration: 28
# Mean reward: 124.6 Std reward: 13.89 Num episodes: 10
# Iteration: 29
# Mean reward: 123.2 Std reward: 15.75 Num episodes: 10
# Iteration: 30
# Mean reward: 147.5 Std reward: 20.8 Num episodes: 10
# Iteration: 31
# Mean reward: 139.1 Std reward: 23.79 Num episodes: 10
# Iteration: 32
# Mean reward: 118.4 Std reward: 11.55 Num episodes: 10
# Iteration: 33
# Mean reward: 135.2 Std reward: 20.76 Num episodes: 10
# Iteration: 34
# Mean reward: 172.0 Std reward: 19.65 Num episodes: 10
# Iteration: 35
# Mean reward: 137.3 Std reward: 7.93 Num episodes: 10
# Iteration: 36
# Mean reward: 219.8 Std reward: 20.68 Num episodes: 10
# Iteration: 37
# Mean reward: 203.0 Std reward: 25.15 Num episodes: 10
# Iteration: 38
# Mean reward: 194.6 Std reward: 29.5 Num episodes: 10
# Iteration: 39
# Mean reward: 207.2 Std reward: 35.78 Num episodes: 10
# Iteration: 40
# Mean reward: 214.4 Std reward: 30.83 Num episodes: 10
# Iteration: 41
# Mean reward: 207.9 Std reward: 20.84 Num episodes: 10
# Iteration: 42
# Mean reward: 221.9 Std reward: 29.25 Num episodes: 10
# Iteration: 43
# Mean reward: 156.9 Std reward: 13.46 Num episodes: 10
# Iteration: 44
# Mean reward: 134.3 Std reward: 10.44 Num episodes: 10
# Iteration: 45
# Mean reward: 131.7 Std reward: 13.69 Num episodes: 10
# Iteration: 46
# Mean reward: 128.9 Std reward: 6.99 Num episodes: 10
# Iteration: 47
# Mean reward: 200.4 Std reward: 16.35 Num episodes: 10
# Iteration: 48
# Mean reward: 255.2 Std reward: 35.5 Num episodes: 10
# Iteration: 49
# Mean reward: 171.8 Std reward: 15.61 Num episodes: 10
# Iteration: 50
# Mean reward: 243.7 Std reward: 38.39 Num episodes: 10
# Iteration: 51
# Mean reward: 220.4 Std reward: 33.62 Num episodes: 10
# Iteration: 52
# Mean reward: 215.7 Std reward: 19.59 Num episodes: 10
# Iteration: 53
# Mean reward: 285.6 Std reward: 55.53 Num episodes: 10
# Iteration: 54
# Mean reward: 306.0 Std reward: 47.07 Num episodes: 10
# Iteration: 55
# Mean reward: 222.2 Std reward: 24.44 Num episodes: 10
# Iteration: 56
# Mean reward: 193.4 Std reward: 9.36 Num episodes: 10
# Iteration: 57
# Mean reward: 163.8 Std reward: 7.97 Num episodes: 10
# Iteration: 58
# Mean reward: 213.4 Std reward: 18.77 Num episodes: 10
# Iteration: 59
# Mean reward: 281.6 Std reward: 28.57 Num episodes: 10
# Iteration: 60
# Mean reward: 465.1 Std reward: 28.68 Num episodes: 10
# Iteration: 61
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 62
# Mean reward: 463.7 Std reward: 36.3 Num episodes: 10
# Iteration: 63
# Mean reward: 424.3 Std reward: 47.84 Num episodes: 10
# Iteration: 64
# Mean reward: 412.3 Std reward: 49.33 Num episodes: 10
# Iteration: 65
# Mean reward: 470.8 Std reward: 29.2 Num episodes: 10
# Iteration: 66
# Mean reward: 458.6 Std reward: 29.89 Num episodes: 10
# Iteration: 67
# Mean reward: 472.3 Std reward: 27.7 Num episodes: 10
# Iteration: 68
# Mean reward: 463.7 Std reward: 36.3 Num episodes: 10
# Iteration: 69
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 70
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 71
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 72
# Mean reward: 497.9 Std reward: 2.1 Num episodes: 10
# Iteration: 73
# Mean reward: 472.5 Std reward: 27.5 Num episodes: 10
# Iteration: 74
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 75
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 76
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 77
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 78
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 79
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 80
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 81
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 82
# Mean reward: 465.5 Std reward: 34.5 Num episodes: 10
# Iteration: 83
# Mean reward: 417.2 Std reward: 48.38 Num episodes: 10
# Iteration: 84
# Mean reward: 458.4 Std reward: 41.6 Num episodes: 10
# Iteration: 85
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 86
# Mean reward: 450.9 Std reward: 49.1 Num episodes: 10
# Iteration: 87
# Mean reward: 358.0 Std reward: 72.3 Num episodes: 10
# Iteration: 88
# Mean reward: 450.8 Std reward: 49.2 Num episodes: 10
# Iteration: 89
# Mean reward: 450.5 Std reward: 49.5 Num episodes: 10
# Iteration: 90
# Mean reward: 405.6 Std reward: 62.93 Num episodes: 10
# Iteration: 91
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 92
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 93
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 94
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 95
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 96
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 97
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 98
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 99
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10

# %%
compare_results(
    {'REINFORCE (linear)': all_results['REINFORCE (linear)'],
     'REINFORCE (neural)': all_results['REINFORCE (neural)'],
     'REINFORCE + baseline': all_results['REINFORCE + baseline']},
    title='Effect of the average baseline'
)

# %%
# Watch the policy trained with the baseline
if is_animated:
    frames = record_episode(render_env, nn_policy_bl)
    animate(frames)

# %% [markdown]
# ---
# # 3. Actor-Critic Methods
# ---
#
# So far the baseline has been either absent (REINFORCE) or a single scalar averaged over the batch (Section 2.3). Both ignore an obvious fact: some states are simply worth more than others. A principled, state-dependent baseline is the state-value function $V(s)$, the expected return from state $s$ under the current policy. Subtracting it from the reward-to-go gives the advantage, which measures how much better an action was than the policy's average behaviour in that state:
#
# $$A_t = \hat{R}_t - V(s_t),$$
#
# where $\hat{R}_t$ is the same reward-to-go used in GPOMDP. Because $V(s_t)$ does not depend on the action, the estimator stays unbiased by the same argument as in Section 2.3, but a good $V$ reduces variance far more than a constant baseline can.
#
# In actor-critic methods we learn $V(s)$ alongside the policy. The model has two parts:
#
# 1. The **critic** estimates $V(s)$ and is trained to minimize the squared error against the observed return.
# 2. The **actor** is the policy $\pi_{\boldsymbol{\theta}}$, trained to increase the probability of advantageous actions.
#
# The two losses we minimize are
#
# $$\mathcal{L}_{\text{actor}} = -\frac{1}{H} \sum_{t=0}^{H-1} \log \pi_{\boldsymbol{\theta}}(a_t \mid s_t)\, A_t,
# \qquad
# \mathcal{L}_{\text{critic}} = \frac{1}{H} \sum_{t=0}^{H-1} \big(\hat{R}_t - V(s_t)\big)^2.$$
#
# The actor loss is exactly the surrogate loss from Section 2, with the learned advantage $A_t$ in place of the reward-to-go. This is the natural endpoint of the variance-reduction story: no baseline, then a constant baseline, then a learned state-dependent baseline.

# %% [markdown]
# ### ⭐ Exercise 3.1 — The actor-critic network
#
# We build a single module with two MLPs, an actor and a critic, both created with `build_mlp` and both controlled by the same `hidden_sizes` argument, so that depth and width are set from the constructor exactly as for the policy in Section 1 (for example `hidden_sizes=(64,)` for one hidden layer, or `(64, 64)` for two). The actor predicts the Gaussian mean, with a learnable log standard deviation; the critic predicts a single state value.
#
# Fill in the `forward` method:
#
# 1. Pass `obs` through `self.actor` to get the mean and build a `Normal` distribution with `self.log_std.exp()`.
# 2. Pass `obs` through `self.critic` and `squeeze(-1)` the result so that the value is one-dimensional.

# %%
class GaussianActorCritic(BasePolicy):
    """Gaussian actor and a value critic, as two separate MLPs.
    Depth and width are set from the constructor via `hidden_sizes`, the same way
    as the policy network in Section 1.
    """
    def __init__(self, s_size, a_size, exploration_std, hidden_sizes=(64,), activation=nn.Tanh):
        super().__init__()
        self.actor = build_mlp(s_size, a_size, hidden_sizes, activation, is_critic=False)
        self.critic = build_mlp(s_size, 1, hidden_sizes, activation, is_critic=True)
        if exploration_std <= 0:
            raise ValueError(f"exploration_std must be positive, got {exploration_std}")
        self.log_std = nn.Parameter(
            torch.log(torch.full((a_size,), float(exploration_std)))
        )
        
    def draw_action(self, obs, deterministic=False):
        """Sample an action; compatible with collect_rollouts and evaluate."""
        obs_t = torch.from_numpy(obs).float()
        with torch.no_grad():
            mean = self.actor(obs_t)
            if deterministic:
                return mean.numpy()
            return Normal(mean, self.log_std.exp()).sample().numpy()

    def forward(self, obs):
        """Return (action distribution, state value)."""
        # --- WRITE YOUR SOLUTION HERE --- #
        mean = self.actor(obs)                           # SOLUTION
        dist = Normal(mean, self.log_std.exp())          # SOLUTION
        value = self.critic(obs).squeeze(-1)             # SOLUTION
        # --- END SOLUTION --- #
        return dist, value

# %% [markdown]
# ### ⭐ Exercise 3.2 — Actor-critic training loop
#
# We reuse `collect_rollouts` from the shared utilities. We pool the transitions from every rollout in the batch into flat tensors, compute the discounted rewards-to-go, and then query the network for $V(s)$ and the log-probabilities of the actions taken. The actor and the critic have separate optimizers, which lets us give the critic a larger learning rate and update it several times per iteration.
#
# The order matters: we update the critic first, for a few epochs on the collected batch, so that by the time we update the actor the value function is already a useful baseline. With only a single critic update per iteration the value estimate stays poor for a long time, the advantage is noisy, and the agent learns slowly and erratically; the extra critic passes are what make the actor-critic both stronger and more reliable than plain REINFORCE.
#
# Fill in the three quantities (the critic loss appears inside the critic-epoch loop, the advantage and actor loss in the actor update):
#
# 1. The advantage $A_t = \hat{R}_t - V(s_t)$. Use `.detach()` on the values so the actor update does not back-propagate through the critic.
# 2. The actor loss $-\tfrac{1}{H}\sum_t \log \pi_{\boldsymbol{\theta}}(a_t \mid s_t)\, A_t$.
# 3. The critic loss $\tfrac{1}{H}\sum_t (\hat{R}_t - V(s_t))^2$.

# %%
def train_actor_critic(env, policy, gamma, m, K, alpha_pi, alpha_v, T, critic_epochs=5, eval_episodes=10, eval_gamma=None):
    """Train an actor-critic policy, with separate optimizers for the actor and critic.

    The critic is updated `critic_epochs` times per iteration. Updating it more than
    once lets the value estimate catch up to the current policy, so the advantage it
    provides is a more useful learning signal for the actor.

    :return: a list of (mean_return, standard_error), one entry per iteration.
    """
    if eval_gamma is None:
        eval_gamma = gamma

    # The actor optimizer also updates the exploration parameter log_std.
    # pi_optimizer = optim.Adam(
    #     list(policy.actor.parameters()) + [policy.log_std], lr=alpha_pi
    # )
    
    pi_optimizer = optim.Adam(policy.actor.parameters(), lr=alpha_pi)
    v_optimizer = optim.Adam(policy.critic.parameters(), lr=alpha_v)

    results = [evaluate(env, policy, T, eval_gamma, eval_episodes)]

    for k in range(K):
        print('Iteration:', k)
        rollouts = collect_rollouts(env, policy, m, T)

        # Gather all transitions in the batch into flat tensors.
        states_list, actions_list, returns_list = [], [], []
        for roll in rollouts:
            H = len(roll)
            states = torch.tensor(np.array([step[0] for step in roll]), dtype=torch.float32)
            actions = torch.tensor(np.array([step[1] for step in roll]), dtype=torch.float32)
            
            returns = torch.zeros(H)
            G = 0.0
            for t in reversed(range(H)):
                G = roll[t][2] + gamma * G
                returns[t] = G

            states_list.append(states)
            actions_list.append(actions)
            returns_list.append(returns)

        states = torch.cat(states_list)
        actions = torch.cat(actions_list)
        returns = torch.cat(returns_list)

        # Train the critic to predict the returns
        for _ in range(critic_epochs):
            _, values = policy(states)
            # --- WRITE YOUR SOLUTION HERE --- #
            critic_loss = ((returns - values) ** 2).mean()      # SOLUTION
            # --- END SOLUTION --- #
            v_optimizer.zero_grad()
            critic_loss.backward()
            v_optimizer.step()

        # Train the actor, using the critic's value as the baseline
        dist, values = policy(states)
        log_probs = dist.log_prob(actions).sum(-1)
        # --- WRITE YOUR SOLUTION HERE --- #
        advantages = returns - values.detach()              # SOLUTION
        actor_loss = -(log_probs * advantages).mean()       # SOLUTION
        # --- END SOLUTION --- #
        pi_optimizer.zero_grad()
        actor_loss.backward()
        pi_optimizer.step()

        results.append(evaluate(env, policy, T, eval_gamma, eval_episodes))

    return results

# %% [markdown]
# ### ⭐ Exercise 3.3 — Run the actor-critic agent and compare
#
# Train the actor-critic agent on the inverted pendulum, then overlay its curve on the REINFORCE curves from Section 2. Because the baseline is now a learned state-value function, the actor-critic update typically has lower variance and reaches a higher return under the same budget.
#
# Things to try: get the return clearly above the REINFORCE curves; compare the shaded variance bands; and, optionally, set `alpha_v = 0` so the critic never learns, which turns the advantage into a fixed (random) baseline and should noticeably hurt performance.

# %%
discount_factor = 1    # @param
batch_size = 50           # @param  (rollouts per iteration, N)
iterations = 100           # @param
actor_lr = 0.005           # @param
critic_lr = 0.005          # @param
trajectory_length = 500   # @param  (native episode cap is 1000)
n_hidden = (32, 32)       # @param
exploration_std = 0.5     # @param
critic_epochs = 15        # @param
seed = 0                  # @param

seed_everything(seed)

# Instantiate and train the actor-critic agent
ac_policy = GaussianActorCritic(s_size, a_size, exploration_std, hidden_sizes=n_hidden)
ac_results = train_actor_critic(env, ac_policy, discount_factor, batch_size,
                                iterations, actor_lr, critic_lr, trajectory_length,
                                critic_epochs=critic_epochs)

all_results['Actor-Critic'] = ac_results
# Out:
# Mean reward: 9.7 Std reward: 2.1 Num episodes: 10
# Iteration: 0
# Mean reward: 9.7 Std reward: 1.43 Num episodes: 10
# Iteration: 1
# Mean reward: 13.9 Std reward: 2.3 Num episodes: 10
# Iteration: 2
# Mean reward: 15.3 Std reward: 2.37 Num episodes: 10
# Iteration: 3
# Mean reward: 18.8 Std reward: 3.47 Num episodes: 10
# Iteration: 4
# Mean reward: 19.3 Std reward: 2.59 Num episodes: 10
# Iteration: 5
# Mean reward: 33.8 Std reward: 7.8 Num episodes: 10
# Iteration: 6
# Mean reward: 29.6 Std reward: 6.34 Num episodes: 10
# Iteration: 7
# Mean reward: 39.5 Std reward: 6.87 Num episodes: 10
# Iteration: 8
# Mean reward: 44.5 Std reward: 8.1 Num episodes: 10
# Iteration: 9
# Mean reward: 44.6 Std reward: 8.74 Num episodes: 10
# Iteration: 10
# Mean reward: 38.6 Std reward: 4.73 Num episodes: 10
# Iteration: 11
# Mean reward: 36.0 Std reward: 3.7 Num episodes: 10
# Iteration: 12
# Mean reward: 67.6 Std reward: 10.09 Num episodes: 10
# Iteration: 13
# Mean reward: 63.7 Std reward: 3.87 Num episodes: 10
# Iteration: 14
# Mean reward: 53.9 Std reward: 4.83 Num episodes: 10
# Iteration: 15
# Mean reward: 54.2 Std reward: 8.32 Num episodes: 10
# Iteration: 16
# Mean reward: 70.0 Std reward: 9.7 Num episodes: 10
# Iteration: 17
# Mean reward: 74.0 Std reward: 7.58 Num episodes: 10
# Iteration: 18
# Mean reward: 78.4 Std reward: 11.85 Num episodes: 10
# Iteration: 19
# Mean reward: 104.3 Std reward: 14.51 Num episodes: 10
# Iteration: 20
# Mean reward: 92.1 Std reward: 12.65 Num episodes: 10
# Iteration: 21
# Mean reward: 81.7 Std reward: 11.12 Num episodes: 10
# Iteration: 22
# Mean reward: 117.1 Std reward: 12.64 Num episodes: 10
# Iteration: 23
# Mean reward: 101.2 Std reward: 15.12 Num episodes: 10
# Iteration: 24
# Mean reward: 99.0 Std reward: 14.15 Num episodes: 10
# Iteration: 25
# Mean reward: 91.4 Std reward: 7.27 Num episodes: 10
# Iteration: 26
# Mean reward: 102.3 Std reward: 14.18 Num episodes: 10
# Iteration: 27
# Mean reward: 107.1 Std reward: 15.0 Num episodes: 10
# Iteration: 28
# Mean reward: 105.3 Std reward: 5.64 Num episodes: 10
# Iteration: 29
# Mean reward: 121.4 Std reward: 9.54 Num episodes: 10
# Iteration: 30
# Mean reward: 115.9 Std reward: 16.21 Num episodes: 10
# Iteration: 31
# Mean reward: 91.1 Std reward: 10.03 Num episodes: 10
# Iteration: 32
# Mean reward: 106.2 Std reward: 12.89 Num episodes: 10
# Iteration: 33
# Mean reward: 107.4 Std reward: 13.64 Num episodes: 10
# Iteration: 34
# Mean reward: 103.8 Std reward: 18.33 Num episodes: 10
# Iteration: 35
# Mean reward: 138.7 Std reward: 18.91 Num episodes: 10
# Iteration: 36
# Mean reward: 110.1 Std reward: 13.58 Num episodes: 10
# Iteration: 37
# Mean reward: 149.4 Std reward: 22.37 Num episodes: 10
# Iteration: 38
# Mean reward: 128.3 Std reward: 14.92 Num episodes: 10
# Iteration: 39
# Mean reward: 108.6 Std reward: 8.14 Num episodes: 10
# Iteration: 40
# Mean reward: 133.0 Std reward: 15.22 Num episodes: 10
# Iteration: 41
# Mean reward: 168.6 Std reward: 29.26 Num episodes: 10
# Iteration: 42
# Mean reward: 169.3 Std reward: 27.54 Num episodes: 10
# Iteration: 43
# Mean reward: 138.5 Std reward: 18.83 Num episodes: 10
# Iteration: 44
# Mean reward: 135.2 Std reward: 17.05 Num episodes: 10
# Iteration: 45
# Mean reward: 183.6 Std reward: 21.67 Num episodes: 10
# Iteration: 46
# Mean reward: 199.6 Std reward: 33.45 Num episodes: 10
# Iteration: 47
# Mean reward: 191.3 Std reward: 25.7 Num episodes: 10
# Iteration: 48
# Mean reward: 186.4 Std reward: 28.92 Num episodes: 10
# Iteration: 49
# Mean reward: 265.9 Std reward: 31.44 Num episodes: 10
# Iteration: 50
# Mean reward: 307.7 Std reward: 37.42 Num episodes: 10
# Iteration: 51
# Mean reward: 319.8 Std reward: 42.63 Num episodes: 10
# Iteration: 52
# Mean reward: 261.6 Std reward: 42.38 Num episodes: 10
# Iteration: 53
# Mean reward: 324.0 Std reward: 52.33 Num episodes: 10
# Iteration: 54
# Mean reward: 287.0 Std reward: 50.17 Num episodes: 10
# Iteration: 55
# Mean reward: 365.2 Std reward: 47.28 Num episodes: 10
# Iteration: 56
# Mean reward: 403.8 Std reward: 43.33 Num episodes: 10
# Iteration: 57
# Mean reward: 346.8 Std reward: 44.77 Num episodes: 10
# Iteration: 58
# Mean reward: 401.2 Std reward: 50.84 Num episodes: 10
# Iteration: 59
# Mean reward: 469.0 Std reward: 14.22 Num episodes: 10
# Iteration: 60
# Mean reward: 458.8 Std reward: 28.62 Num episodes: 10
# Iteration: 61
# Mean reward: 474.1 Std reward: 25.9 Num episodes: 10
# Iteration: 62
# Mean reward: 484.8 Std reward: 15.2 Num episodes: 10
# Iteration: 63
# Mean reward: 464.8 Std reward: 29.42 Num episodes: 10
# Iteration: 64
# Mean reward: 462.1 Std reward: 30.16 Num episodes: 10
# Iteration: 65
# Mean reward: 490.1 Std reward: 9.9 Num episodes: 10
# Iteration: 66
# Mean reward: 453.1 Std reward: 46.9 Num episodes: 10
# Iteration: 67
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 68
# Mean reward: 454.3 Std reward: 45.7 Num episodes: 10
# Iteration: 69
# Mean reward: 483.4 Std reward: 14.81 Num episodes: 10
# Iteration: 70
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 71
# Mean reward: 486.8 Std reward: 13.2 Num episodes: 10
# Iteration: 72
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 73
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 74
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 75
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 76
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 77
# Mean reward: 473.9 Std reward: 26.1 Num episodes: 10
# Iteration: 78
# Mean reward: 459.6 Std reward: 40.4 Num episodes: 10
# Iteration: 79
# Mean reward: 451.9 Std reward: 48.1 Num episodes: 10
# Iteration: 80
# Mean reward: 450.2 Std reward: 35.98 Num episodes: 10
# Iteration: 81
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 82
# Mean reward: 458.9 Std reward: 41.1 Num episodes: 10
# Iteration: 83
# Mean reward: 456.0 Std reward: 43.23 Num episodes: 10
# Iteration: 84
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 85
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 86
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 87
# Mean reward: 465.6 Std reward: 22.95 Num episodes: 10
# Iteration: 88
# Mean reward: 481.1 Std reward: 16.8 Num episodes: 10
# Iteration: 89
# Mean reward: 389.4 Std reward: 52.67 Num episodes: 10
# Iteration: 90
# Mean reward: 474.0 Std reward: 26.0 Num episodes: 10
# Iteration: 91
# Mean reward: 438.4 Std reward: 46.13 Num episodes: 10
# Iteration: 92
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 93
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 94
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 95
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 96
# Mean reward: 454.8 Std reward: 45.2 Num episodes: 10
# Iteration: 97
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10
# Iteration: 98
# Mean reward: 473.5 Std reward: 26.5 Num episodes: 10
# Iteration: 99
# Mean reward: 500.0 Std reward: 0.0 Num episodes: 10

# %%
compare_results(
    {'REINFORCE (linear)': all_results['REINFORCE (linear)'],
     'REINFORCE (neural)': all_results['REINFORCE (neural)'],
     'REINFORCE + baseline': all_results['REINFORCE + baseline'],
     'Actor-Critic': all_results['Actor-Critic']},
    title='Actor-Critic vs. REINFORCE'
)

# %%
# Watch the trained actor-critic agent
if is_animated:
    frames = record_episode(render_env, ac_policy)
    animate(frames)

# %% [markdown]
# ---
# # 4. Putting it all together
# ---
#
# We have run four methods on the inverted pendulum with the same evaluation protocol, storing each training curve in `all_results`. The plot below overlays them, with the average return on each training iteration.
#
# The methods are comparable iteration by iteration because they all collect the same number of rollouts per iteration, so each point on the x-axis corresponds to the same amount of collected experience. (The more advanced methods make slightly better use of that experience, but the data budget per iteration is the same.)

# %%
# Overlay every experiment we ran
compare_results(all_results, title='Policy gradient methods on InvertedPendulum')

# %% [markdown]
# Reading the curves from earlier to later in the notebook:
#
# - The **linear policy** already learns to balance, because a linear feedback law is a reasonable controller for this task, though its curve is among the noisiest.
# - The **neural policy** is more expressive and learns at least as well, usually a little more smoothly.
# - **Adding the average baseline** leaves the expected gradient unchanged but reduces the variance of the updates, which tends to show up as a steadier curve.
# - The **actor-critic** replaces the fixed baseline with a learned, state-dependent value function, and gives the strongest and most stable result of the four.
#
# The exact ordering varies between runs because of the randomness in sampling. Each training cell calls `seed_everything` before building its policy, so re-running a cell reproduces its curve; change the `seed` parameter to see how stable each method is.

# %% [markdown]
# ---
# # 5. A harder task, and a state-of-the-art baseline
# ---
#
# On the inverted pendulum every method we built eventually works, because the task is easy. Real problems are harder, and the differences between algorithms become much clearer. To see this, we move to [HalfCheetah](https://gymnasium.farama.org/environments/mujoco/half_cheetah/), a classic continuous-control benchmark where the agent controls a two-legged robot and is rewarded for running forward as fast as possible. The state has 17 dimensions and the action has 6, and every episode runs for a fixed number of steps.
#
# We will do two things: run our own actor-critic on this task, and compare it against a tested implementation of **Proximal Policy Optimization** (PPO) from the [Stable-Baselines3](https://stable-baselines3.readthedocs.io/) library.
#
# PPO is, in spirit, exactly where this notebook has been heading. It is an actor-critic method, with a policy and a value function and advantages computed just as we did. Its main addition is a safeguard on how much the policy is allowed to change at each update: instead of taking an unrestricted gradient step, it optimizes a *clipped* objective that keeps the new policy close to the old one. This makes learning far more stable and lets the algorithm reuse each batch of data for several updates. It is the same family of ideas we have built, with the engineering needed to make it robust.

# %% [markdown]
# ## 5.1 Our actor-critic on HalfCheetah
#
# We reuse our `GaussianActorCritic` and `train_actor_critic` without changing them, only pointing them at the new environment. The reward here can be negative (the robot is penalised for moving backwards or for large efforts), so returns start below zero. Since every HalfCheetah episode has the same fixed length, we report the total episode reward (the undiscounted return), which is the standard score for this benchmark.

# %%
hard_env_id = "HalfCheetah-v5"
hard_env = gym.make(hard_env_id)
hard_render_env = gym.make(hard_env_id, render_mode="rgb_array")

hard_s_size = hard_env.observation_space.shape[0]
hard_a_size = hard_env.action_space.shape[0]
print("HalfCheetah: state", hard_s_size, "action", hard_a_size,
      "episode length", hard_env.spec.max_episode_steps)
# Out:
# HalfCheetah: state 17 action 6 episode length 1000

# %%
hard_results = {}

discount_factor = 0.99        # @param
batch_size = 10            # @param  (rollouts per iteration, N)
iterations = 100           # @param
actor_lr = 0.001           # @param
critic_lr = 0.001          # @param
trajectory_length = 1000   # @param
n_hidden = (64, 32)        # @param
exploration_std = 0.1
critic_epochs = 100        # @param
seed = 0                   # @param


seed_everything(seed)

hard_ac_policy = GaussianActorCritic(hard_s_size, hard_a_size, exploration_std, hidden_sizes=n_hidden)
hard_ac_results = train_actor_critic(hard_env, hard_ac_policy, discount_factor, batch_size,
                                     iterations, actor_lr, critic_lr, trajectory_length,
                                     critic_epochs=critic_epochs, eval_episodes=3, eval_gamma=1.0)

# hard_act_policy = GaussianPolicy(hard_s_size, hard_a_size, exploration_std, hidden_sizes=n_hidden)
# hard_ac_results = train(hard_env, hard_act_policy, discount_factor, batch_size,
#                          iterations, actor_lr, trajectory_length,
#                          baseline=True)

hard_results['Actor-Critic'] = hard_ac_results
# Out:
# Mean reward: -54.01 Std reward: 1.56 Num episodes: 3
# Iteration: 0
# Mean reward: -7.57 Std reward: 3.16 Num episodes: 3
# Iteration: 1
# Mean reward: 13.16 Std reward: 6.15 Num episodes: 3
# Iteration: 2
# Mean reward: 45.59 Std reward: 2.05 Num episodes: 3
# Iteration: 3
# Mean reward: 91.77 Std reward: 7.45 Num episodes: 3
# Iteration: 4
# Mean reward: 161.2 Std reward: 3.76 Num episodes: 3
# Iteration: 5
# Mean reward: 236.32 Std reward: 4.84 Num episodes: 3
# Iteration: 6
# Mean reward: 287.23 Std reward: 2.47 Num episodes: 3
# Iteration: 7
# Mean reward: 364.27 Std reward: 8.27 Num episodes: 3
# Iteration: 8
# Mean reward: 458.67 Std reward: 10.68 Num episodes: 3
# Iteration: 9
# Mean reward: 538.52 Std reward: 7.82 Num episodes: 3
# Iteration: 10
# Mean reward: 609.52 Std reward: 7.05 Num episodes: 3
# Iteration: 11
# Mean reward: 699.13 Std reward: 11.24 Num episodes: 3
# Iteration: 12
# Mean reward: 749.95 Std reward: 16.4 Num episodes: 3
# Iteration: 13
# Mean reward: 792.19 Std reward: 4.03 Num episodes: 3
# Iteration: 14
# Mean reward: 847.99 Std reward: 9.63 Num episodes: 3
# Iteration: 15
# Mean reward: 893.89 Std reward: 8.72 Num episodes: 3
# Iteration: 16
# Mean reward: 931.2 Std reward: 2.87 Num episodes: 3
# Iteration: 17
# Mean reward: 985.86 Std reward: 11.8 Num episodes: 3
# Iteration: 18
# Mean reward: 1040.22 Std reward: 4.65 Num episodes: 3
# Iteration: 19
# Mean reward: 1060.72 Std reward: 5.18 Num episodes: 3
# Iteration: 20
# Mean reward: 1070.96 Std reward: 8.3 Num episodes: 3
# Iteration: 21
# Mean reward: 1073.71 Std reward: 5.96 Num episodes: 3
# Iteration: 22
# Mean reward: 1096.5 Std reward: 12.15 Num episodes: 3
# Iteration: 23
# Mean reward: 1117.39 Std reward: 6.11 Num episodes: 3
# Iteration: 24
# Mean reward: 1133.23 Std reward: 12.43 Num episodes: 3
# Iteration: 25
# Mean reward: 1128.3 Std reward: 3.48 Num episodes: 3
# Iteration: 26
# Mean reward: 1160.36 Std reward: 12.53 Num episodes: 3
# Iteration: 27
# Mean reward: 1146.3 Std reward: 17.55 Num episodes: 3
# Iteration: 28
# Mean reward: 1187.02 Std reward: 14.67 Num episodes: 3
# Iteration: 29
# Mean reward: 1187.07 Std reward: 8.38 Num episodes: 3
# Iteration: 30
# Mean reward: 1198.98 Std reward: 18.03 Num episodes: 3
# Iteration: 31
# Mean reward: 1208.4 Std reward: 21.33 Num episodes: 3
# Iteration: 32
# Mean reward: 1220.36 Std reward: 7.77 Num episodes: 3
# Iteration: 33
# Mean reward: 1212.68 Std reward: 7.31 Num episodes: 3
# Iteration: 34
# Mean reward: 1235.21 Std reward: 13.46 Num episodes: 3
# Iteration: 35
# Mean reward: 1221.53 Std reward: 40.75 Num episodes: 3
# Iteration: 36
# Mean reward: 1250.64 Std reward: 9.67 Num episodes: 3
# Iteration: 37
# Mean reward: 1289.95 Std reward: 15.3 Num episodes: 3
# Iteration: 38
# Mean reward: 814.06 Std reward: 438.43 Num episodes: 3
# Iteration: 39
# Mean reward: 1259.87 Std reward: 17.73 Num episodes: 3
# Iteration: 40
# Mean reward: 1266.32 Std reward: 9.76 Num episodes: 3
# Iteration: 41
# Mean reward: 1238.05 Std reward: 20.79 Num episodes: 3
# Iteration: 42
# Mean reward: 1265.22 Std reward: 12.22 Num episodes: 3
# Iteration: 43
# Mean reward: 1264.26 Std reward: 42.29 Num episodes: 3
# Iteration: 44
# Mean reward: 1306.13 Std reward: 28.69 Num episodes: 3
# Iteration: 45
# Mean reward: 1299.16 Std reward: 33.17 Num episodes: 3
# Iteration: 46
# Mean reward: 1331.89 Std reward: 26.54 Num episodes: 3
# Iteration: 47
# Mean reward: 1303.23 Std reward: 26.1 Num episodes: 3
# Iteration: 48
# Mean reward: 1384.2 Std reward: 17.8 Num episodes: 3
# Iteration: 49
# Mean reward: 1303.49 Std reward: 29.99 Num episodes: 3
# Iteration: 50
# Mean reward: 1359.51 Std reward: 23.5 Num episodes: 3
# Iteration: 51
# Mean reward: 1344.87 Std reward: 14.65 Num episodes: 3
# Iteration: 52
# Mean reward: 1009.61 Std reward: 378.81 Num episodes: 3
# Iteration: 53
# Mean reward: 1356.08 Std reward: 22.7 Num episodes: 3
# Iteration: 54
# Mean reward: 1374.24 Std reward: 21.09 Num episodes: 3
# Iteration: 55
# Mean reward: 1367.74 Std reward: 17.82 Num episodes: 3
# Iteration: 56
# Mean reward: 1314.68 Std reward: 15.41 Num episodes: 3
# Iteration: 57
# Mean reward: 1354.27 Std reward: 15.8 Num episodes: 3
# Iteration: 58
# Mean reward: 1368.62 Std reward: 28.6 Num episodes: 3
# Iteration: 59
# Mean reward: 1357.22 Std reward: 19.93 Num episodes: 3
# Iteration: 60
# Mean reward: 1311.17 Std reward: 17.69 Num episodes: 3
# Iteration: 61
# Mean reward: 1347.66 Std reward: 51.9 Num episodes: 3
# Iteration: 62
# Mean reward: 1382.38 Std reward: 27.79 Num episodes: 3
# Iteration: 63
# Mean reward: 1336.61 Std reward: 17.39 Num episodes: 3
# Iteration: 64
# Mean reward: 1317.98 Std reward: 67.39 Num episodes: 3
# Iteration: 65
# Mean reward: 1292.76 Std reward: 28.5 Num episodes: 3
# Iteration: 66
# Mean reward: 1343.36 Std reward: 29.68 Num episodes: 3
# Iteration: 67
# Mean reward: 966.87 Std reward: 389.74 Num episodes: 3
# Iteration: 68
# Mean reward: 1400.92 Std reward: 10.12 Num episodes: 3
# Iteration: 69
# Mean reward: 936.24 Std reward: 395.92 Num episodes: 3
# Iteration: 70
# Mean reward: 1386.32 Std reward: 31.97 Num episodes: 3
# Iteration: 71
# Mean reward: 1417.38 Std reward: 14.26 Num episodes: 3
# Iteration: 72
# Mean reward: 1429.56 Std reward: 13.05 Num episodes: 3
# Iteration: 73
# Mean reward: 1375.65 Std reward: 28.18 Num episodes: 3
# Iteration: 74
# Mean reward: 1386.26 Std reward: 16.75 Num episodes: 3
# Iteration: 75
# Mean reward: 1365.28 Std reward: 12.02 Num episodes: 3
# Iteration: 76
# Mean reward: 1347.42 Std reward: 7.87 Num episodes: 3
# Iteration: 77
# Mean reward: 1324.26 Std reward: 13.36 Num episodes: 3
# Iteration: 78
# Mean reward: 1208.18 Std reward: 8.52 Num episodes: 3
# Iteration: 79
# Mean reward: 1133.91 Std reward: 15.71 Num episodes: 3
# Iteration: 80
# Mean reward: 1221.14 Std reward: 23.25 Num episodes: 3
# Iteration: 81
# Mean reward: 1122.37 Std reward: 165.98 Num episodes: 3
# Iteration: 82
# Mean reward: 1330.66 Std reward: 16.99 Num episodes: 3
# Iteration: 83
# Mean reward: 1356.77 Std reward: 6.12 Num episodes: 3
# Iteration: 84
# Mean reward: 1313.99 Std reward: 16.31 Num episodes: 3
# Iteration: 85
# Mean reward: 1355.32 Std reward: 16.03 Num episodes: 3
# Iteration: 86
# Mean reward: 1327.81 Std reward: 25.14 Num episodes: 3
# Iteration: 87
# Mean reward: 1354.54 Std reward: 25.19 Num episodes: 3
# Iteration: 88
# Mean reward: 1314.46 Std reward: 16.28 Num episodes: 3
# Iteration: 89
# Mean reward: 1282.79 Std reward: 41.12 Num episodes: 3
# Iteration: 90
# Mean reward: 1303.01 Std reward: 28.1 Num episodes: 3
# Iteration: 91
# Mean reward: 1152.5 Std reward: 199.43 Num episodes: 3
# Iteration: 92
# Mean reward: 1301.87 Std reward: 9.41 Num episodes: 3
# Iteration: 93
# Mean reward: 1091.33 Std reward: 270.17 Num episodes: 3
# Iteration: 94
# Mean reward: 1336.88 Std reward: 38.69 Num episodes: 3
# Iteration: 95
# Mean reward: 1330.51 Std reward: 4.94 Num episodes: 3
# Iteration: 96
# Mean reward: 942.49 Std reward: 382.06 Num episodes: 3
# Iteration: 97
# Mean reward: 1353.88 Std reward: 13.34 Num episodes: 3
# Iteration: 98
# Mean reward: 1326.62 Std reward: 9.97 Num episodes: 3
# Iteration: 99
# Mean reward: 1149.61 Std reward: 194.87 Num episodes: 3

# %% [markdown]
# ## 5.2 PPO with Stable-Baselines3
#
# Setting up and training PPO takes only a few lines. To make the comparison fair, we give PPO the same number of environment interactions our actor-critic used, namely `batch_size * trajectory_length * iterations` steps, and we evaluate it at regular checkpoints so its curve can be drawn on the same iteration axis.

# %%
from stable_baselines3 import PPO


class SB3Policy:
    """Wrap a Stable-Baselines3 model so it exposes the same draw_action interface
    as our own policies, which lets us reuse evaluate() and record_episode()."""
    def __init__(self, model):
        self.model = model

    def draw_action(self, obs, deterministic=True):
        action, _ = self.model.predict(obs, deterministic=deterministic)
        return action

# %%
# Same interaction budget as our actor-critic above
steps_per_iteration = batch_size * trajectory_length
total_steps = steps_per_iteration * iterations

seed_everything(seed)
model = PPO("MlpPolicy", gym.make(hard_env_id), seed=seed, verbose=0)
ppo_policy = SB3Policy(model)

# Train in `iterations` chunks, evaluating after each so the curve aligns with ours
ppo_results = [evaluate(hard_env, ppo_policy, 1000, 1.0, num_episodes=3)]
for k in range(iterations):
    print('Iteration:', k)
    model.learn(total_timesteps=steps_per_iteration, reset_num_timesteps=False)
    ppo_results.append(evaluate(hard_env, ppo_policy, 1000, 1.0, num_episodes=3))

hard_results['PPO (Stable-Baselines3)'] = ppo_results

# %%
# Compare our actor-critic against PPO on HalfCheetah, iteration by iteration
compare_results(hard_results, title='Actor-Critic vs. PPO on HalfCheetah')

# %%
# Watch the trained PPO agent run
if is_animated:
    frames = record_episode(hard_render_env, ppo_policy)
    animate(frames)

# %% [markdown]
# On this harder task the gap is clear. Our actor-critic improves slowly, if at all, within the small budget, while PPO learns to run and reaches a much higher return from the same amount of experience. It is the same actor-critic idea we implemented, plus the clipped update and a number of careful engineering choices, and that combination is what makes the difference on a difficult problem.
#
# The lesson is not that our implementations were wrong; they were deliberately simple, so that the mechanics stay visible. Once you understand those mechanics, the practical approach to a real problem is to build on a tested library like Stable-Baselines3 rather than re-implementing everything, and to spend your effort on the environment, the reward, and the evaluation instead.

# %% [markdown]
# ---
# # 🥳 Congratulations on completing the RL Basics II Tutorial!
#
# You implemented and ran the full progression of policy gradient methods, each step motivated by reducing the variance of the one before, and then saw how they scale to a harder task:
#
# - Section 1, the policy gradient objective and the score function, computed by hand for a linear policy and then handed to autograd for a neural policy.
# - Section 2, REINFORCE with the reward-to-go for causal credit assignment, and variance reduction through an average baseline.
# - Section 3, actor-critic, where the baseline becomes a learned state-value function and the reward-to-go becomes the advantage.
# - Section 5, a harder task (HalfCheetah) and a comparison with PPO from Stable-Baselines3.
